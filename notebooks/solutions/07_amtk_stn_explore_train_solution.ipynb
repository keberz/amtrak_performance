# %% [markdown]
# # Explore: Amtrak Trains
#
# ## Intercity Passenger Rail Service Station Performance Metrics
#
# The Amtrak [network](https://www.amtrak.com/content/dam/projects/dotcom/english/public/documents/Maps/Amtrak-System-Map-020923.pdf)
# is a passenger rail service that provides intercity rail service in the
# continental United States and to select Canadian cities. The network is operated by the
# [National Railroad Passenger Corporation](https://railroads.dot.gov/passenger-rail/amtrak/amtrak),
# a federally chartered for-profit corporation that receives some state funding and covers its
# operating costs by selling tickets and providing other services.
#
# This notebook commences exploration of the augmented quarterly
# [Amtrak](https://www.amtrak.com/home.html) station performance metrics. The goal is to better
# understand individual Amtrak train performance and identify potential areas for further analysis.
#
# ### Variable names
#
# A number of variable names in this project leverage the following abbreviations. The naming
# strategy is to strike a balance between brevity and readability:
#
# * `amtk`: Amtrak (reporting mark)
# * `chrt`: chart
# * `cols`: columns
# * `const`: constant
# * `cwd`: current working directory
# * `eb`: eastbound direction of travel
# * `lm`: linear model
# * `mi`: miles
# * `mm`: minutes (ISO 8601)
# * `nb`: northbound direction of travel
# * `psgr`: passenger
# * `qtr`: quarter
# * `rte`: route
# * `sb`: southbound direction of travel
# * `stats`: summary statistics
# * `stn`: station
# * `stns`: stations
# * `svc`: service
# * `trn`: train
# * `wb`: westbound direction of travel

# %%
import numpy as np
import pandas as pd
import pathlib as pl
import tomllib as tl

import fra_amtrak.amtk_detrain as detrn
import fra_amtrak.amtk_frame as frm
import fra_amtrak.amtk_network as ntwk
import fra_amtrak.chart_box_preagg as boxp
import fra_amtrak.chart_hist as hst
import fra_amtrak.chart_title as ttl

# %% [markdown]
# ## 1.0 Read files
#
# ### 1.1 Resolve paths

# %%
parent_path = pl.Path.cwd() # current working directory
parent_path
# Out:
# PosixPath('/home/jovyan/work/assignments/Course4')

# %% [markdown]
# ### 1.2 Load constants
#
# Load a companion [TOML](https://toml.io/en/) file containing constants.

# %%
filepath = parent_path.joinpath("notebook.toml")
with open(filepath, "rb") as file_obj:
    const = tl.load(file_obj)

# Access constants
AGG = const["agg"]
CHRT_BAR = const["chart"]["bar"]
COLORS = const["colors"]
COLS = const["columns"]
DIRECTION = const["train"]["direction"]
SUB_SVC = const["train"]["sub_service"]
TRN = const["train"]

# %% [markdown]
# ### 1.3 Retrieve performance data

# %%
filepath = parent_path.joinpath("data", "processed", "station_performance_metrics-v1p2.csv")
trains = pd.read_csv(
    filepath, dtype={"Address 02": "str", "ZIP Code": "str"}, low_memory=False
)  # avoid DtypeWarning
trains.shape
# Out:
# (68412, 24)

# %%
trains.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68412 entries, 0 to 68411
# Data columns (total 24 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Fiscal Year                               68412 non-null  int64
#  1   Fiscal Quarter                            68412 non-null  int64
#  2   Service Line                              68412 non-null  object
#  3   Service                                   68412 non-null  object
#  4   Sub Service                               68412 non-null  object
#  5   Route Miles                               68412 non-null  int64
#  6   Train Number                              68412 non-null  int64
#  7   Arrival Station Code                      68412 non-null  object
#  8   Arrival Station                           68412 non-null  object
#  9   Arrival Station Type                      68386 non-null  object
#  10  City                                      68404 non-null  object
#  11  Address 01                                68404 non-null  object
#  12  Address 02                                126 non-null    object
#  13  ZIP Code                                  68404 non-null  object
#  14  State                                     68412 non-null  object
#  15  Division                                  68412 non-null  object
#  16  Region                                    68412 non-null  object
#  17  Country                                   68412 non-null  object
#  18  Latitude                                  68404 non-null  float64
#  19  Longitude                                 68404 non-null  float64
#  20  Total Detraining Customers                68412 non-null  int64
#  21  Late Detraining Customers                 68412 non-null  int64
#  22  Late to Total Detraining Customers Ratio  68412 non-null  float64
#  23  Late Detraining Customers Avg Min Late    57373 non-null  float64
# dtypes: float64(4), int64(6), object(14)
# memory usage: 12.5+ MB

# %%
trains.head(3)
# Out:
#    Fiscal Year  Fiscal Quarter   Service Line            Service  \
# 0         2024               3  Long Distance         Auto Train
# 1         2024               3  Long Distance         Auto Train
# 2         2024               3  Long Distance  California Zephyr
#
#          Sub Service  Route Miles  Train Number Arrival Station Code  \
# 0         Auto Train          914            52                  LOR
# 1         Auto Train          914            53                  SFA
# 2  California Zephyr         2408             5                  BRL
#
#         Arrival Station                  Arrival Station Type  ...     State  \
# 0   Lorton (Auto Train)  Station Building (with waiting room)  ...  Virginia
# 1  Sanford (Auto Train)  Station Building (with waiting room)  ...   Florida
# 2            Burlington  Station Building (with waiting room)  ...      Iowa
#
#              Division   Region        Country   Latitude  Longitude  \
# 0      South Atlantic    South  United States  38.708143 -77.220942
# 1      South Atlantic    South  United States  28.808544 -81.291274
# 2  West North Central  Midwest  United States  40.805788 -91.101951
#
#   Total Detraining Customers Late Detraining Customers  \
# 0                      42445                     23316
# 1                      28034                     18439
# 2                        557                       223
#
#    Late to Total Detraining Customers Ratio  \
# 0                                   0.54932
# 1                                   0.65774
# 2                                   0.40036
#
#    Late Detraining Customers Avg Min Late
# 0                                    95.0
# 1                                    91.0
# 2                                    54.0
#
# [3 rows x 24 columns]

# %% [markdown]
# ## 2.0 Select trains: Northeast Corridor (NEC)
#
# Amtrak's Northeast Corridor (NEC) is the busiest passenger rail corridor in the United States. It is the only Amtrak line that operates high-speed Acela Express service. The NEC is a shared asset with commuter rail operators, including the Massachusetts Bay Transportation Authority (MBTA), Metro-North Railroad, New Jersey Transit, Southeastern Pennsylvania Transportation Authority (SEPTA), and the Maryland Transit Administration (MTA).

# %% [markdown]
# ### 2.1 _Acela Express_ (Boston - New York - Philadelphia - Washington, D.C.)  [1 pt]
#
# Amtrak's [_Acela_](https://www.amtrak.com/acela-train) service is a high-speed rail service(`150` mph | `240` km/h) that operates along the Northeast Corridor (NEC) between Boston, MA and Washington, D.C. The service features multiple departure daily. The service features express trains that make limited stops and regional trains that make all stops.
#
# This section focuses on the _Acela Express_ service. Retrieve the _Acela Express_ performance data by calling the appropriate `amtk_network` function. Assign the return value of the function call to a variable named `acela_xp`.

# %%
# YOUR CODE HERE
acela_xp = ntwk.by_sub_service(trains, "Acela Express")
acela_xp
# Out:
#       Fiscal Year  Fiscal Quarter        Service Line        Service  \
# 0            2023               1  Northeast Corridor  Acela Express
# 1            2023               1  Northeast Corridor  Acela Express
# 2            2023               1  Northeast Corridor  Acela Express
# 3            2023               1  Northeast Corridor  Acela Express
# 4            2023               1  Northeast Corridor  Acela Express
# ...           ...             ...                 ...            ...
# 2448         2021               4  Northeast Corridor  Acela Express
# 2449         2021               4  Northeast Corridor  Acela Express
# 2450         2021               4  Northeast Corridor  Acela Express
# 2451         2021               4  Northeast Corridor  Acela Express
# 2452         2021               4  Northeast Corridor  Acela Express
#
#         Sub Service  Route Miles  Train Number Arrival Station Code  \
# 0     Acela Express          457          2103                  BAL
# 1     Acela Express          457          2103                  MET
# 2     Acela Express          457          2103                  NWK
# 3     Acela Express          457          2103                  PHL
# 4     Acela Express          457          2103                  TRE
# ...             ...          ...           ...                  ...
# 2448  Acela Express          457          2259                  RTE
# 2449  Acela Express          457          2259                  STM
# 2450  Acela Express          457          2259                  TRE
# 2451  Acela Express          457          2259                  WAS
# 2452  Acela Express          457          2259                  WIL
#
#                       Arrival Station                  Arrival Station Type  \
# 0            Baltimore (Penn Station)  Station Building (with waiting room)
# 1                  Metropark (Iselin)  Station Building (with waiting room)
# 2               Newark (Penn Station)  Station Building (with waiting room)
# 3     Philadelphia (Gray 30th St Sta)  Station Building (with waiting room)
# 4                             Trenton  Station Building (with waiting room)
# ...                               ...                                   ...
# 2448             Route 128 (Westwood)  Station Building (with waiting room)
# 2449                         Stamford  Station Building (with waiting room)
# 2450                          Trenton  Station Building (with waiting room)
# 2451                       Washington  Station Building (with waiting room)
# 2452                       Wilmington  Station Building (with waiting room)
#
#       ...                 State         Division     Region        Country  \
# 0     ...              Maryland   South Atlantic      South  United States
# 1     ...            New Jersey  Middle Atlantic  Northeast  United States
# 2     ...            New Jersey  Middle Atlantic  Northeast  United States
# 3     ...          Pennsylvania  Middle Atlantic  Northeast  United States
# 4     ...            New Jersey  Middle Atlantic  Northeast  United States
# ...   ...                   ...              ...        ...            ...
# 2448  ...         Massachusetts      New England  Northeast  United States
# 2449  ...           Connecticut      New England  Northeast  United States
# 2450  ...            New Jersey  Middle Atlantic  Northeast  United States
# 2451  ...  District of Columbia   South Atlantic      South  United States
# 2452  ...              Delaware   South Atlantic      South  United States
#
#        Latitude  Longitude Total Detraining Customers  \
# 0     39.307302 -76.615688                       1502
# 1     40.568056 -74.329583                          7
# 2     40.734706 -74.164750                         10
# 3     39.955615 -75.181041                       1730
# 4     40.219011 -74.754440                        132
# ...         ...        ...                        ...
# 2448  42.210242 -71.147894                          2
# 2449  41.047130 -73.542160                        110
# 2450  40.219011 -74.754440                         49
# 2451  38.896993 -77.006422                       1555
# 2452  39.737263 -75.551095                        151
#
#      Late Detraining Customers  Late to Total Detraining Customers Ratio  \
# 0                           57                                   0.03795
# 1                            1                                   0.14286
# 2                            0                                   0.00000
# 3                           58                                   0.03353
# 4                            6                                   0.04545
# ...                        ...                                       ...
# 2448                         0                                   0.00000
# 2449                        18                                   0.16364
# 2450                        16                                   0.32653
# 2451                       759                                   0.48810
# 2452                        98                                   0.64901
#
#       Late Detraining Customers Avg Min Late
# 0                                       79.0
# 1                                       19.0
# 2                                        NaN
# 3                                       76.0
# 4                                       60.0
# ...                                      ...
# 2448                                     NaN
# 2449                                    13.0
# 2450                                    62.0
# 2451                                    41.0
# 2452                                    21.0
#
# [2453 rows x 24 columns]

# %%
#hidden tests are within this cell

# %% [markdown]
# ### 2.2 _Acela Express_: on-time performance metrics (entire period) [1 pt]
#
# _Acela Express_ performance data is a compilation of quarterly metrics that focus on late
# detraining passengers. Detraining assengers are considered on-time if they arrive at their
# destination no later than fifteen (`15`) minutes after their scheduled arrival time. All other
# detraining passengers are considered late.

# %%
# Total train arrivals
acela_xp_trn_arrivals = acela_xp.shape[0]

# Detraining totals
acela_xp_detrn = acela_xp[COLS["total_detrn"]].sum()
acela_xp_detrn_late = acela_xp[COLS["late_detrn"]].sum()
acela_xp_detrn_on_time = acela_xp_detrn - acela_xp_detrn_late

print(
    f"Train Arrivals: {acela_xp_trn_arrivals}",
    f"Total Detraining Customers: {acela_xp_detrn}",
    f"Late Detraining Customers: {acela_xp_detrn_late}",
    f"On-Time Detraining Customers: {acela_xp_detrn_on_time}",
    sep="\n",
)

# Compute summary statistics
acela_xp_stats = detrn.get_sum_stats(acela_xp, AGG["columns"], AGG["funcs"])
acela_xp_stats
# Out:
# Train Arrivals: 2453
# Total Detraining Customers: 3310356
# Late Detraining Customers: 576649
# On-Time Detraining Customers: 2733707
#    Train Arrivals  Total Detraining Customers sum  \
# 0            2453                       3310356.0
#
#    Total Detraining Customers mean  Total Detraining Customers median  \
# 0                        1349.5132                              377.0
#
#    Total Detraining Customers std  Late Detraining Customers sum  \
# 0                       2404.6604                       576649.0
#
#    Late Detraining Customers mean  Late Detraining Customers median  \
# 0                        235.0791                              48.0
#
#    Late Detraining Customers std  Late to Total Detraining Customers Ratio  \
# 0                        501.387                                    0.1742
#
#   Late Detraining Customers Avg Min Late mean  \
# 0                                        None
#
#    Total On Time Detraining Customers sum
# 0                               2733707.0

# %%
#hidden tests are within this cell

# %% [markdown]
# ### 2.3 _Acela Express_ trains [1 pt]
#
# Each _Acela Express_ train is identified by a unique train number.
#
# Create a `DataFrame` named `acela_xp_trns` that contains one row for each train comprising the _Acela Express_ service. Include the following columns in the `DataFrame` in the order specified:
#
# 1. "Service Line"
# 2. "Service"
# 3. "Sub Service"
# 4. "Route Miles"
# 5. "Train Number"
#
# Reset the index (set `drop=True`) when creating the new `DataFrame`.

# %%
acela_xp_trns = acela_xp.drop_duplicates(subset='Train Number', ignore_index=True)
acela_xp_trns = acela_xp_trns[["Service Line", "Service", "Sub Service", "Route Miles", "Train Number"]]
acela_xp_trns.sort_values(by="Train Number", inplace=True, ignore_index=True)
acela_xp_trns
# Out:
#           Service Line        Service    Sub Service  Route Miles  \
# 0   Northeast Corridor  Acela Express  Acela Express          457
# 1   Northeast Corridor  Acela Express  Acela Express          457
# 2   Northeast Corridor  Acela Express  Acela Express          457
# 3   Northeast Corridor  Acela Express  Acela Express          457
# 4   Northeast Corridor  Acela Express  Acela Express          457
# 5   Northeast Corridor  Acela Express  Acela Express          457
# 6   Northeast Corridor  Acela Express  Acela Express          457
# 7   Northeast Corridor  Acela Express  Acela Express          457
# 8   Northeast Corridor  Acela Express  Acela Express          457
# 9   Northeast Corridor  Acela Express  Acela Express          457
# 10  Northeast Corridor  Acela Express  Acela Express          457
# 11  Northeast Corridor  Acela Express  Acela Express          457
# 12  Northeast Corridor  Acela Express  Acela Express          457
# 13  Northeast Corridor  Acela Express  Acela Express          457
# 14  Northeast Corridor  Acela Express  Acela Express          457
# 15  Northeast Corridor  Acela Express  Acela Express          457
# 16  Northeast Corridor  Acela Express  Acela Express          457
# 17  Northeast Corridor  Acela Express  Acela Express          457
# 18  Northeast Corridor  Acela Express  Acela Express          457
# 19  Northeast Corridor  Acela Express  Acela Express          457
# 20  Northeast Corridor  Acela Express  Acela Express          457
# 21  Northeast Corridor  Acela Express  Acela Express          457
# 22  Northeast Corridor  Acela Express  Acela Express          457
# 23  Northeast Corridor  Acela Express  Acela Express          457
# 24  Northeast Corridor  Acela Express  Acela Express          457
# 25  Northeast Corridor  Acela Express  Acela Express          457
# 26  Northeast Corridor  Acela Express  Acela Express          457
# 27  Northeast Corridor  Acela Express  Acela Express          457
# 28  Northeast Corridor  Acela Express  Acela Express          457
# 29  Northeast Corridor  Acela Express  Acela Express          457
# 30  Northeast Corridor  Acela Express  Acela Express          457
# 31  Northeast Corridor  Acela Express  Acela Express          457
# 32  Northeast Corridor  Acela Express  Acela Express          457
# 33  Northeast Corridor  Acela Express  Acela Express          457
# 34  Northeast Corridor  Acela Express  Acela Express          457
# 35  Northeast Corridor  Acela Express  Acela Express          457
# 36  Northeast Corridor  Acela Express  Acela Express          457
# 37  Northeast Corridor  Acela Express  Acela Express          457
# 38  Northeast Corridor  Acela Express  Acela Express          457
# 39  Northeast Corridor  Acela Express  Acela Express          457
# 40  Northeast Corridor  Acela Express  Acela Express          457
# 41  Northeast Corridor  Acela Express  Acela Express          457
# 42  Northeast Corridor  Acela Express  Acela Express          457
# 43  Northeast Corridor  Acela Express  Acela Express          457
# 44  Northeast Corridor  Acela Express  Acela Express          457
# 45  Northeast Corridor  Acela Express  Acela Express          457
# 46  Northeast Corridor  Acela Express  Acela Express          457
# 47  Northeast Corridor  Acela Express  Acela Express          457
# 48  Northeast Corridor  Acela Express  Acela Express          457
# 49  Northeast Corridor  Acela Express  Acela Express          457
# 50  Northeast Corridor  Acela Express  Acela Express          457
# 51  Northeast Corridor  Acela Express  Acela Express          457
# 52  Northeast Corridor  Acela Express  Acela Express          457
# 53  Northeast Corridor  Acela Express  Acela Express          457
# 54  Northeast Corridor  Acela Express  Acela Express          457
# 55  Northeast Corridor  Acela Express  Acela Express          457
# 56  Northeast Corridor  Acela Express  Acela Express          457
#
#     Train Number
# 0           2103
# 1           2106
# 2           2107
# 3           2109
# 4           2121
# 5           2122
# 6           2126
# 7           2128
# 8           2150
# 9           2151
# 10          2152
# 11          2153
# 12          2154
# 13          2155
# 14          2156
# 15          2158
# 16          2159
# 17          2160
# 18          2163
# 19          2164
# 20          2165
# 21          2166
# 22          2167
# 23          2168
# 24          2169
# 25          2170
# 26          2172
# 27          2173
# 28          2175
# 29          2190
# 30          2193
# 31          2203
# 32          2205
# 33          2213
# 34          2217
# 35          2218
# 36          2220
# 37          2222
# 38          2224
# 39          2226
# 40          2233
# 41          2235
# 42          2239
# 43          2248
# 44          2249
# 45          2250
# 46          2251
# 47          2252
# 48          2253
# 49          2254
# 50          2255
# 51          2256
# 52          2257
# 53          2259
# 54          2275
# 55          2290
# 56          2292

# %%
#hidden tests are within this cell

# %% [markdown]
# ### 2.4 _Acela Express_: mean late arrival times summary statistics
#
# Review the central tendency, dispersion, and shape for the mean late arrival times of _Acela Express_ trains. Call the custom function named `frm.describe_numeric_column()` to return a dictionary of summary statistics.

# %%
# Drop missing values
acela_xp_avg_mm_late = acela_xp[COLS["late_detrn_avg_mm_late"]].dropna().reset_index(drop=True)

# Call the custom frm.describe_numeric_column() function again
acela_xp_avg_mm_late_describe = frm.describe_numeric_column(acela_xp_avg_mm_late)
acela_xp_avg_mm_late_describe
# Out:
# {'type': pandas.core.series.Series,
#  'name': 'Late Detraining Customers Avg Min Late',
#  'values': {'non_null': np.int64(1986),
#   'missing': np.int64(0),
#   'dtype': dtype('float64')},
#  'center': {'mean': np.float64(30.614300100704934),
#   'median': 26.0,
#   'mode': np.float64(21.0)},
#  'position': {'min': 11.0,
#   '25%': np.float64(20.0),
#   '50%': np.float64(26.0),
#   '75%': np.float64(35.0),
#   'max': 305.0},
#  'spread': {'variance': 441.80179036631756,
#   'std': 21.019081577612223,
#   'range': 294.0,
#   'iqr': np.float64(15.0)},
#  'shape': {'skewness': np.float64(5.309165458832421),
#   'kurtosis': np.float64(51.41815789389943)}}

# %% [markdown]
# The skewness and kurtosis values returned suggest that the distribution of mean late arrival times of _Acela Express_ trains are positively skewed and features features a sharper peak and heavier right tail than a normal distribution. Let's confirm this visually by generating a histogram.

# %% [markdown]
# ### 2.5 _Acela Express_: visualize distribution of mean late arrival times
#
# Visualize mean late arrival times for the entire period. The data is binned prior to plotting.
#
# #### 2.5.1 Create the chart data

# %%
# Convert to DataFrame
acela_xp_avg_mm_late = acela_xp_avg_mm_late.to_frame(name=COLS["avg_mm_late"])

# Get mean and standard deviation
mu = acela_xp_avg_mm_late_describe["center"]["mean"]
sigma = acela_xp_avg_mm_late_describe["spread"]["std"]

# Get max value (for x-axis ticks); pad max value for chart display
max_val = acela_xp_avg_mm_late_describe["position"]["max"]
max_val_ceil = (np.ceil(max_val / 10) * 10).astype(int)

# Create bins
acela_xp_mm_late, bins, num_bins, bin_width = frm.create_bins(
    acela_xp_avg_mm_late, COLS["avg_mm_late"], 10
)

# Bin the data
chrt_data = frm.bin_data(acela_xp_mm_late, COLS["avg_mm_late"], bins)
# chrt_data

# %% [markdown]
# #### 2.5.2 Generate the histogram

# %%
# Chart title
title_txt = f"Amtrak {SUB_SVC['ace_xp']} Service Late Detraining Passengers"
title = ttl.format_title(acela_xp_stats, title_txt)

# Tooltips
tooltip_config = [
    {"shorthand": "bin_center:Q", "title": "Average Minutes Late", "format": None},
    {"shorthand": "count:Q", "title": "Late Arrivals Count", "format": None},
]

# Create and display the histogram
chart = hst.create_histogram(
    frame=chrt_data,
    x_shorthand="bin_center:Q",
    x_title="Average Minutes Late",
    y_shorthand="count:Q",
    y_title="Late Arrivals Count",
    y_stack=False,
    line_shorthand="Avg Min Late:Q",
    mu=mu,
    sigma=sigma,
    num_bins=num_bins,
    bin_width=bin_width,
    x_tick_count_max=max_val_ceil,
    bar_color=COLORS["amtk_blue"],
    mu_color=COLORS["amtk_red"],
    sigma_color=COLORS["anth_gray"],
    tooltip_config=tooltip_config,
    title=title,
)
chart.display()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### 2.6 _Acela Express_, Trains 2155 & 2154
#
# _Acela_ trains 2155 (southbound) and 2154 (northbound) operate daily between [South Station](https://www.amtrak.com/stations/bos) Boston, MA ([BOS](https://www.amtrak.com/stations/bos)) and [Union Station](https://www.amtrak.com/stations/was) Washington, D.C. ([WAS](https://www.amtrak.com/stations/was)).
#
# #### 2.6.1 _Acela Express_ Train 2155, southbound, detraining passengers summary statistics [1 pt]
#
# Departing daily from [South Station](https://www.amtrak.com/stations/bos), Boston, MA ([BOS](https://www.amtrak.com/stations/bos)).

# %%
# Base columns for routes
rte_cols = [
    COLS["trn"],
    COLS["station_code"],
    COLS["station"],
    COLS["state"],
    COLS["lat"],
    COLS["lon"],
]

# Train 2154 southbound
amtk_2155 = ntwk.by_train_number(trains, 2155)
amtk_2155_rte = ntwk.create_route(amtk_2155, TRN["2154"]["direction"])
amtk_2155_rte_stats = detrn.get_route_sum_stats(
    amtk_2155_rte,
    COLS["station_code"],
    AGG["columns"],
    AGG["funcs"],
    rte_cols,
)
amtk_2155_rte_stats.sort_values(by=[COLS["lat"]], ascending=False, inplace=True)

amtk_2155_rte_stats
# Out:
#     Train Number Arrival Station Code                         Arrival Station  \
# 12          2155                  BBY               Boston (Back Bay Station)
# 11          2155                  RTE                    Route 128 (Westwood)
# 10          2155                  PVD                     Providence (Amtrak)
# 9           2155                  NHV               New Haven (Union Station)
# 8           2155                  STM                                Stamford
# 7           2155                  NYP  NY Moynihan Train Hall at Penn Station
# 6           2155                  NWK                   Newark (Penn Station)
# 5           2155                  MET                      Metropark (Iselin)
# 4           2155                  PHL         Philadelphia (Gray 30th St Sta)
# 3           2155                  WIL                              Wilmington
# 2           2155                  BAL                Baltimore (Penn Station)
# 1           2155                  BWI   BWI Thurgood Marshall Airport Station
# 0           2155                  WAS                              Washington
#
#                    State   Latitude  Longitude  Train Arrivals  \
# 12         Massachusetts  42.347317 -71.075828               9
# 11         Massachusetts  42.210242 -71.147894              10
# 10          Rhode Island  41.829490 -71.413478              12
# 9            Connecticut  41.297714 -72.926670              12
# 8            Connecticut  41.047130 -73.542160              12
# 7               New York  40.751038 -73.996327              12
# 6             New Jersey  40.734706 -74.164750              12
# 5             New Jersey  40.568056 -74.329583              11
# 4           Pennsylvania  39.955615 -75.181041              12
# 3               Delaware  39.737263 -75.551095              12
# 2               Maryland  39.307302 -76.615688              12
# 1               Maryland  39.192362 -76.694300               3
# 0   District of Columbia  38.896993 -77.006422              12
#
#     Total Detraining Customers sum  Total Detraining Customers mean  \
# 12                              17                           1.8889
# 11                              28                           2.8000
# 10                            6158                         513.1667
# 9                             4000                         333.3333
# 8                             7912                         659.3333
# 7                           122032                       10169.3333
# 6                             5434                         452.8333
# 5                             3661                         332.8182
# 4                            30483                        2540.2500
# 3                             9161                         763.4167
# 2                            13187                        1098.9167
# 1                             2446                         815.3333
# 0                           127575                       10631.2500
#
#     Total Detraining Customers median  Total Detraining Customers std  \
# 12                                2.0                          0.9280
# 11                                2.0                          2.2010
# 10                              502.5                        117.8889
# 9                               348.5                         85.8342
# 8                               672.5                        141.1500
# 7                             10580.0                       1206.4759
# 6                               480.0                         95.5004
# 5                               387.0                        174.7277
# 4                              2516.0                        362.5107
# 3                               755.5                        117.2088
# 2                              1100.0                        156.4425
# 1                               839.0                        136.0527
# 0                             11164.0                       1824.6040
#
#     Late Detraining Customers sum  Late Detraining Customers mean  \
# 12                              0                          0.0000
# 11                              1                          0.1000
# 10                            219                         18.2500
# 9                             442                         36.8333
# 8                            1535                        127.9167
# 7                           20019                       1668.2500
# 6                            1177                         98.0833
# 5                             957                         87.0000
# 4                            8892                        741.0000
# 3                            3191                        265.9167
# 2                            3270                        272.5000
# 1                             691                        230.3333
# 0                           32188                       2682.3333
#
#     Late Detraining Customers median  Late Detraining Customers std  \
# 12                               0.0                         0.0000
# 11                               0.0                         0.3162
# 10                              13.5                        13.9618
# 9                               16.0                        38.7294
# 8                               99.5                        91.3957
# 7                             1296.0                       968.1477
# 6                               79.5                        68.8285
# 5                               63.0                        64.8521
# 4                              682.5                       289.7519
# 3                              228.5                        94.7527
# 2                              253.0                       110.8164
# 1                              177.0                       114.7098
# 0                             2833.0                      1046.0782
#
#     Late to Total Detraining Customers Ratio  \
# 12                                    0.0000
# 11                                    0.0357
# 10                                    0.0356
# 9                                     0.1105
# 8                                     0.1940
# 7                                     0.1640
# 6                                     0.2166
# 5                                     0.2614
# 4                                     0.2917
# 3                                     0.3483
# 2                                     0.2480
# 1                                     0.2825
# 0                                     0.2523
#
#     Late Detraining Customers Avg Min Late mean  \
# 12                                          NaN
# 11                                      16.0000
# 10                                      24.2727
# 9                                       24.1667
# 8                                       21.3333
# 7                                       28.2500
# 6                                       26.1667
# 5                                       22.2000
# 4                                       23.1667
# 3                                       24.8333
# 2                                       27.6667
# 1                                       30.6667
# 0                                       29.5833
#
#     Total On Time Detraining Customers sum
# 12                                      17
# 11                                      27
# 10                                    5939
# 9                                     3558
# 8                                     6377
# 7                                   102013
# 6                                     4257
# 5                                     2704
# 4                                    21591
# 3                                     5970
# 2                                     9917
# 1                                     1755
# 0                                    95387

# %%
#hidden tests are within this cell

# %% [markdown]
# ##### 2.6.1.1 Write to file [1 pt]
#
# Write `amtk_2155_rte_stats` to a CSV file named `stu-amtk_2155_rte_stats.csv`. Store the file in the `data/student` directory. Then compare it to the accompanying `fxt-amtk_2155_rte_stats.csv` file. It must match line for line, character for character.

# %%
filepath = parent_path.joinpath("data", "student", "stu-amtk_2155_rte_stats.csv")
amtk_2155_rte_stats.to_csv(filepath, index=False)

# %%
#hidden tests are within this cell

# %% [markdown]
# #### 2.6.2 _Acela Express_ Train 2155: late detraining metrics (fiscal year and quarter)
#
# Review the central tendency, dispersion, and shape for the mean late arrival times of _Acela Express_ trains. Call the custom function named `frm.describe_numeric_column()` to return a dictionary of summary statistics.

# %%
# Drop missing values
amtk_2155_avg_mm_late = amtk_2155[COLS["late_detrn_avg_mm_late"]].dropna().reset_index(drop=True)

# Describe the column
amtk_2155_avg_mm_late_describe = frm.describe_numeric_column(amtk_2155_avg_mm_late)
amtk_2155_avg_mm_late_describe
# Out:
# {'type': pandas.core.series.Series,
#  'name': 'Late Detraining Customers Avg Min Late',
#  'values': {'non_null': np.int64(121),
#   'missing': np.int64(0),
#   'dtype': dtype('float64')},
#  'center': {'mean': np.float64(25.28099173553719),
#   'median': 23.0,
#   'mode': np.float64(21.0)},
#  'position': {'min': 12.0,
#   '25%': np.float64(20.0),
#   '50%': np.float64(23.0),
#   '75%': np.float64(29.0),
#   'max': 77.0},
#  'spread': {'variance': 79.07038567493116,
#   'std': 8.892153039333678,
#   'range': 65.0,
#   'iqr': np.float64(9.0)},
#  'shape': {'skewness': np.float64(2.2531334382697175),
#   'kurtosis': np.float64(9.855369686527695)}}

# %% [markdown]
# ##### 2.6.2.1 Retrieve the data

# %%
# Base columns for average minutes late
cols = [COLS["year"], COLS["quarter"], COLS["late_detrn_avg_mm_late"]]

# Chart data
chrt_data = detrn.get_qtr_avg_min_late(
    amtk_2155_rte, cols, COLS["year_quarter"], [COLORS["amtk_blue"], COLORS["amtk_red"]]
)
chrt_data
# Out:
#     Fiscal Year Quarter  Late Detraining Customers Avg Min Late    Color
# 0                2021Q4                                    29.0  #00537e
# 1                2021Q4                                    25.0  #00537e
# 2                2021Q4                                    28.0  #00537e
# 3                2021Q4                                    25.0  #00537e
# 4                2021Q4                                    23.0  #00537e
# ..                  ...                                     ...      ...
# 136              2024Q3                                    25.0  #ef3824
# 137              2024Q3                                    17.0  #ef3824
# 138              2024Q3                                    14.0  #ef3824
# 139              2024Q3                                    14.0  #ef3824
# 140              2024Q3                                     NaN  #ef3824
#
# [141 rows x 3 columns]

# %% [markdown]
# ##### 2.6.2.2 Preaggregate the data
#
# Attempting to instantiate an instance of a Vega-Altair [`alt.Chart()`](https://altair-viz.github.io/user_guide/generated/toplevel/altair.Chart.html) class by passing to it a dataset comprising more than `5000` rows will trigger a `MaxRowsError`. You can disable the `MaxRows` check by calling `alt.data_transformers.disable_max_rows()` method. However, disabling the check may result in performance issues, including browser crashes.
#
# The preferred approach when [working with large datasets](https://altair-viz.github.io/user_guide/large_datasets.html#large-datasets) is to _preaggregate_ the data before generating a plot. This can be achieved "manually"&mdash;the approach adopted in this notebook&mdash;or by [installing](https://altair-viz.github.io/user_guide/large_datasets.html#installing-vegafusion[) and [enabling](https://altair-viz.github.io/user_guide/large_datasets.html#enabling-the-vegafusion-data-transformer) Altair's companion [vegafusion](https://vegafusion.io/) data transformer package.

# %%
# Base columns for aggregation statistics
cols = [COLS["year_quarter"], COLS["late_detrn_avg_mm_late"]]

# Pre-aggregate the data
chrt_data = frm.aggregate_data(chrt_data, cols)

# %% [markdown]
# ##### 2.6.2.3 Generate box plots
#
# Visualize the distribution of mean late arrival times for late detraining passengers. Illustrate with box plots.

# %%
# Create chart title
txt = TRN["2155"]
title_txt = (
    f"Amtrak {txt['name']} Train {txt['number']} Late Detraining Passengers\n"
    f"{txt['route']} ({txt['direction']})"
)
title = ttl.format_title(amtk_2155_rte_stats, title_txt)

# Create and display the vertical boxplot
chart_vertical = boxp.create_boxplot(
    data=chrt_data,
    x_shorthand="Fiscal Year Quarter:N",
    x_title="Period",
    y_shorthand="Late Detraining Customers Avg Min Late:Q",
    y_title="Average Minutes Late",
    box_size=20,
    outlier_shorthand="outliers:Q",
    color_shorthand="Color:N",
    chart_title=title,
    orient=boxp.Orient.VERTICAL,
)
chart_vertical.display()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# #### 2.6.3 _Acela Express_ Train 2154, northbound, detraining passengers summary statistics [1 pt]
#
# Departing daily from [Union Station](https://www.amtrak.com/stations/was), Washington, D.C.
# ([WAS](https://www.amtrak.com/stations/was)).
#
# Review previous code employed to generate summary statistics for an Amtrak train. Then leverage functions available in the `amtk_network` and `amtk_detrain` modules to create three new `DataFrame` objects named `amtk_2154`, `amtk_2154_rte`, and `amtk_2154_rte_stats`, respectively.

# %%
# YOUR CODE HERE
# Base columns for routes
rte_cols = [
    COLS["trn"],
    COLS["station_code"],
    COLS["station"],
    COLS["state"],
    COLS["lat"],
    COLS["lon"],
]

# Train 2154 southbound
amtk_2154 = ntwk.by_train_number(trains, 2154)
amtk_2154_rte = ntwk.create_route(amtk_2154, TRN["2154"]["direction"])
amtk_2154_rte_stats = detrn.get_route_sum_stats(
    amtk_2154_rte,
    COLS["station_code"],
    AGG["columns"],
    AGG["funcs"],
    rte_cols,
)
amtk_2154_rte_stats.sort_values(by=[COLS["lat"]], ascending=True, inplace=True)

filepath = parent_path.joinpath("data", "student", "stu-amtk_2154_rte_stats.csv")
amtk_2154_rte_stats.to_csv(filepath, index=False)

amtk_2154_rte_stats
# Out:
#     Train Number Arrival Station Code                         Arrival Station  \
# 0           2154                  BWI   BWI Thurgood Marshall Airport Station
# 1           2154                  BAL                Baltimore (Penn Station)
# 2           2154                  WIL                              Wilmington
# 3           2154                  PHL         Philadelphia (Gray 30th St Sta)
# 4           2154                  TRE                                 Trenton
# 5           2154                  NWK                   Newark (Penn Station)
# 6           2154                  NYP  NY Moynihan Train Hall at Penn Station
# 7           2154                  STM                                Stamford
# 8           2154                  NHV               New Haven (Union Station)
# 9           2154                  PVD                     Providence (Amtrak)
# 10          2154                  RTE                    Route 128 (Westwood)
# 11          2154                  BBY               Boston (Back Bay Station)
# 12          2154                  BOS                  Boston (South Station)
#
#             State   Latitude  Longitude  Train Arrivals  \
# 0        Maryland  39.192362 -76.694300              12
# 1        Maryland  39.307302 -76.615688              12
# 2        Delaware  39.737263 -75.551095              12
# 3    Pennsylvania  39.955615 -75.181041              12
# 4      New Jersey  40.219011 -74.754440               1
# 5      New Jersey  40.734706 -74.164750              12
# 6        New York  40.751038 -73.996327              12
# 7     Connecticut  41.047130 -73.542160              12
# 8     Connecticut  41.297714 -72.926670              11
# 9    Rhode Island  41.829490 -71.413478              12
# 10  Massachusetts  42.210242 -71.147894              12
# 11  Massachusetts  42.347317 -71.075828              12
# 12  Massachusetts  42.352311 -71.055304              12
#
#     Total Detraining Customers sum  Total Detraining Customers mean  \
# 0                             1278                         106.5000
# 1                             1669                         139.0833
# 2                             4089                         340.7500
# 3                            25334                        2111.1667
# 4                               28                          28.0000
# 5                             9512                         792.6667
# 6                           133093                       11091.0833
# 7                             7586                         632.1667
# 8                             7418                         674.3636
# 9                            19647                        1637.2500
# 10                           23663                        1971.9167
# 11                           38232                        3186.0000
# 12                           77402                        6450.1667
#
#     Total Detraining Customers median  Total Detraining Customers std  \
# 0                                95.0                         48.6051
# 1                               151.5                         48.9702
# 2                               382.5                        129.1955
# 3                              2221.0                        518.8538
# 4                                28.0                             NaN
# 5                               842.5                        127.6446
# 6                             11278.0                       1207.6415
# 7                               645.0                         81.4559
# 8                               722.0                        162.3387
# 9                              1668.0                        193.5830
# 10                             1902.0                        376.4058
# 11                             3231.5                        361.1137
# 12                             6602.5                        761.3909
#
#     Late Detraining Customers sum  Late Detraining Customers mean  \
# 0                              41                          3.4167
# 1                              83                          6.9167
# 2                             275                         22.9167
# 3                            2468                        205.6667
# 4                               1                          1.0000
# 5                            1683                        140.2500
# 6                           14971                       1247.5833
# 7                            2130                        177.5000
# 8                            1596                        145.0909
# 9                            6986                        582.1667
# 10                           6278                        523.1667
# 11                          10064                        838.6667
# 12                          21484                       1790.3333
#
#     Late Detraining Customers median  Late Detraining Customers std  \
# 0                                3.0                         2.8110
# 1                                4.0                         6.0221
# 2                               22.0                        13.8003
# 3                              240.5                        77.4331
# 4                                1.0                            NaN
# 5                              125.0                        71.9319
# 6                             1098.5                       634.6931
# 7                              146.5                        94.4029
# 8                              144.0                        68.5835
# 9                              574.5                       224.3264
# 10                             501.0                       263.6530
# 11                             716.5                       378.7550
# 12                            1630.5                       764.6153
#
#     Late to Total Detraining Customers Ratio  \
# 0                                     0.0321
# 1                                     0.0497
# 2                                     0.0673
# 3                                     0.0974
# 4                                     0.0357
# 5                                     0.1769
# 6                                     0.1125
# 7                                     0.2808
# 8                                     0.2152
# 9                                     0.3556
# 10                                    0.2653
# 11                                    0.2632
# 12                                    0.2776
#
#     Late Detraining Customers Avg Min Late mean  \
# 0                                       27.7000
# 1                                       26.2727
# 2                                       24.5000
# 3                                       25.0000
# 4                                       11.0000
# 5                                       23.0833
# 6                                       28.0833
# 7                                       22.0833
# 8                                       25.3636
# 9                                       27.0833
# 10                                      30.0833
# 11                                      31.5000
# 12                                      32.1667
#
#     Total On Time Detraining Customers sum
# 0                                     1237
# 1                                     1586
# 2                                     3814
# 3                                    22866
# 4                                       27
# 5                                     7829
# 6                                   118122
# 7                                     5456
# 8                                     5822
# 9                                    12661
# 10                                   17385
# 11                                   28168
# 12                                   55918

# %%
#hidden tests are within this cell

# %% [markdown]
# ##### 2.6.3.1 Write to file [1 pt]
#
# Write `amtk_2154_stats` to a CSV file named `stu-amtk_2154_route_stats.csv`. Store the file in the
# `data/student` directory. Then compare it to the accompanying `fxt-amtk-2154_route_stats.csv` file.
# It must match line for line, character for character.

# %%
# YOUR CODE HERE
filepath = parent_path.joinpath("data", "student", "stu-amtk_2154_rte_stats.csv")
amtk_2154_rte_stats.to_csv(filepath, index=False)

# %%
#hidden tests are within this cell

# %% [markdown]
# #### 2.6.4 _Acela Express_ Train 2154: late detraining metrics (fiscal year and quarter)
#
# Review the central tendency, dispersion, and shape for the mean late arrival times of _Acela Express_ Train 2154. Call the custom function named `frm.describe_numeric_column()` to return a dictionary of summary statistics. Then visualize each fiscal year and quarter data with a box plot.

# %%
# Drop missing values
amtk_2154_avg_mm_late = amtk_2154[COLS["late_detrn_avg_mm_late"]].dropna().reset_index(drop=True)

# Describe the column
amtk_2154_avg_mm_late_describe = frm.describe_numeric_column(amtk_2154_avg_mm_late)
amtk_2154_avg_mm_late_describe
# Out:
# {'type': pandas.core.series.Series,
#  'name': 'Late Detraining Customers Avg Min Late',
#  'values': {'non_null': np.int64(141),
#   'missing': np.int64(0),
#   'dtype': dtype('float64')},
#  'center': {'mean': np.float64(26.80141843971631),
#   'median': 26.0,
#   'mode': np.float64(21.0)},
#  'position': {'min': 11.0,
#   '25%': np.float64(20.0),
#   '50%': np.float64(26.0),
#   '75%': np.float64(31.0),
#   'max': 56.0},
#  'spread': {'variance': 83.81742654508611,
#   'std': 9.155185773379266,
#   'range': 45.0,
#   'iqr': np.float64(11.0)},
#  'shape': {'skewness': np.float64(0.8783906477596932),
#   'kurtosis': np.float64(0.6057990936284594)}}

# %% [markdown]
# ##### 2.6.4.1 Retrieve the chart data

# %%
# Base columns for average minutes late
cols = [COLS["year"], COLS["quarter"], COLS["late_detrn_avg_mm_late"]]

# Chart data
chrt_data = detrn.get_qtr_avg_min_late(
    amtk_2154_rte, cols, COLS["year_quarter"], [COLORS["amtk_blue"], COLORS["amtk_red"]]
)
# chrt_data

# %% [markdown]
# ##### 2.6.4.2 Preaggregate the data

# %%
# Base columns for aggregation statistics
cols = [COLS["year_quarter"], COLS["late_detrn_avg_mm_late"]]

# Pre-aggregate the data
chrt_data = frm.aggregate_data(chrt_data, cols)

# %% [markdown]
# ##### 2.6.4.3 Generate box plots

# %%
# Create chart title
txt = TRN["2154"]
title_txt = (
    f"Amtrak {txt['name']} Train {txt['number']} Late Detraining Passengers\n"
    f"{txt['route']} ({txt['direction']})"
)
title = ttl.format_title(amtk_2154_rte_stats, title_txt)

# Create and display the vertical boxplot
chart_vertical = boxp.create_boxplot(
    data=chrt_data,
    x_shorthand="Fiscal Year Quarter:N",
    x_title="Period",
    y_shorthand="Late Detraining Customers Avg Min Late:Q",
    y_title="Average Minutes Late",
    box_size=20,
    outlier_shorthand="outliers:Q",
    color_shorthand="Color:N",
    chart_title=title,
    orient=boxp.Orient.VERTICAL,
)
chart_vertical.display()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## 3.0 Select trains: State Supported Michigan Service
#
# Amtrak's state-supported trains are funded by state governments. These services are typically shorter in length and operate within a single state or across multiple states.
#
# ### 3.1 _Pacific Surfliner_ Service (San Luis Obispo - Santa Barbara - Los Angeles - San Diego) [1 pt]
#
# Amtrak's [Pacific Surfliner](https://www.amtrak.com/pacific-surfliner-train) service operates between San Luis Obispo, CA ([SLO](https://www.amtrak.com/stations/slo)) and [Santa Fe Depot](https://www.amtrak.com/stations/san), San Diego, CA ([SAN](https://www.amtrak.com/stations/san)). The service features multiple departures daily and serves a number of popular destinations, including Santa Barbara, CA ([SBA](https://www.amtrak.com/stations/sba)), Los Angeles, CA ([LAX](https://www.amtrak.com/stations/lax)), Anaheim, CA ([ANA](https://www.amtrak.com/stations/ana)), and San Juan Capistrano, CA ([SNC](https://www.amtrak.com/stations/snc)).
#
# Retrieve the _Pacific Surfliner_ performance data by calling the appropriate `amtk_network` function. Assign the return value of the function call to a variable named `surf`.

# %%
surf = ntwk.by_sub_service(trains, "Pacific Surfliner")
surf
# Out:
#       Fiscal Year  Fiscal Quarter     Service Line            Service  \
# 0            2024               3  State Supported  Pacific Surfliner
# 1            2024               3  State Supported  Pacific Surfliner
# 2            2024               3  State Supported  Pacific Surfliner
# 3            2024               3  State Supported  Pacific Surfliner
# 4            2024               3  State Supported  Pacific Surfliner
# ...           ...             ...              ...                ...
# 4443         2021               4  State Supported  Pacific Surfliner
# 4444         2021               4  State Supported  Pacific Surfliner
# 4445         2021               4  State Supported  Pacific Surfliner
# 4446         2021               4  State Supported  Pacific Surfliner
# 4447         2021               4  State Supported  Pacific Surfliner
#
#             Sub Service  Route Miles  Train Number Arrival Station Code  \
# 0     Pacific Surfliner          351           562                  ANA
# 1     Pacific Surfliner          351           562                  FUL
# 2     Pacific Surfliner          351           562                  IRV
# 3     Pacific Surfliner          351           562                  OLT
# 4     Pacific Surfliner          351           562                  OSD
# ...                 ...          ...           ...                  ...
# 4443  Pacific Surfliner          351          1793                  OSD
# 4444  Pacific Surfliner          351          1793                  SOL
# 4445  Pacific Surfliner          351          1796                  CPN
# 4446  Pacific Surfliner          351          1796                  OXN
# 4447  Pacific Surfliner          351          1796                  VEC
#
#            Arrival Station                  Arrival Station Type  ...  \
# 0                  Anaheim  Station Building (with waiting room)  ...
# 1                Fullerton  Station Building (with waiting room)  ...
# 2                   Irvine  Station Building (with waiting room)  ...
# 3     San Diego (Old Town)            Platform only (no shelter)  ...
# 4                Oceanside  Station Building (with waiting room)  ...
# ...                    ...                                   ...  ...
# 4443             Oceanside  Station Building (with waiting room)  ...
# 4444          Solana Beach            Platform only (no shelter)  ...
# 4445           Carpinteria                 Platform with Shelter  ...
# 4446                Oxnard  Station Building (with waiting room)  ...
# 4447               Ventura                 Platform with Shelter  ...
#
#            State Division Region        Country   Latitude   Longitude  \
# 0     California  Pacific   West  United States  33.803803 -117.877308
# 1     California  Pacific   West  United States  33.868969 -117.922849
# 2     California  Pacific   West  United States  33.656771 -117.733695
# 3     California  Pacific   West  United States  32.755266 -117.200073
# 4     California  Pacific   West  United States  33.192515 -117.379430
# ...          ...      ...    ...            ...        ...         ...
# 4443  California  Pacific   West  United States  33.192515 -117.379430
# 4444  California  Pacific   West  United States  32.992937 -117.271135
# 4445  California  Pacific   West  United States  34.396780 -119.522975
# 4446  California  Pacific   West  United States  34.199241 -119.175978
# 4447  California  Pacific   West  United States  34.276929 -119.299918
#
#      Total Detraining Customers Late Detraining Customers  \
# 0                           289                        20
# 1                           360                        19
# 2                          1516                        28
# 3                          1732                       248
# 4                           720                        71
# ...                         ...                       ...
# 4443                        639                         0
# 4444                          9                         0
# 4445                          6                         2
# 4446                        288                       133
# 4447                        105                        31
#
#       Late to Total Detraining Customers Ratio  \
# 0                                      0.06920
# 1                                      0.05278
# 2                                      0.01847
# 3                                      0.14319
# 4                                      0.09861
# ...                                        ...
# 4443                                   0.00000
# 4444                                   0.00000
# 4445                                   0.33333
# 4446                                   0.46181
# 4447                                   0.29524
#
#       Late Detraining Customers Avg Min Late
# 0                                       39.0
# 1                                       32.0
# 2                                       37.0
# 3                                       36.0
# 4                                       33.0
# ...                                      ...
# 4443                                     NaN
# 4444                                     NaN
# 4445                                    30.0
# 4446                                    36.0
# 4447                                    34.0
#
# [4448 rows x 24 columns]

# %%
#hidden tests are within this cell

# %% [markdown]
# ### 3.2 _Pacific Surfliner_: on-time performance metrics (entire period) [1 pt]
#
# Pacific Surfliner performance data is a compilation of quarterly metrics that focus on late detraining passengers. Detraining assengers are considered on-time if they arrive at their destination no later than fifteen (`15`) minutes after their scheduled arrival time. All other detraining passengers are considered late.

# %%
# Total train arrivals
surf_trn_arrivals = surf.shape[0]

# Detraining totals
surf_detrn = surf[COLS["total_detrn"]].sum()
surf_detrn_late = surf[COLS["late_detrn"]].sum()
surf_detrn_on_time = surf_detrn - surf_detrn_late

print(
    f"Train Arrivals: {surf_trn_arrivals}",
    f"Total Detraining Customers: {surf_detrn}",
    f"Late Detraining Customers: {surf_detrn_late}",
    f"On-Time Detraining Customers: {surf_detrn_on_time}",
    sep="\n",
)

# Compute summary statistics
surf_stats = detrn.get_sum_stats(surf, AGG["columns"], AGG["funcs"])
surf_stats
# Out:
# Train Arrivals: 4448
# Total Detraining Customers: 5040187
# Late Detraining Customers: 932657
# On-Time Detraining Customers: 4107530
#    Train Arrivals  Total Detraining Customers sum  \
# 0            4448                       5040187.0
#
#    Total Detraining Customers mean  Total Detraining Customers median  \
# 0                        1133.1356                              478.5
#
#    Total Detraining Customers std  Late Detraining Customers sum  \
# 0                       1976.3956                       932657.0
#
#    Late Detraining Customers mean  Late Detraining Customers median  \
# 0                        209.6801                              58.0
#
#    Late Detraining Customers std  Late to Total Detraining Customers Ratio  \
# 0                       445.2761                                     0.185
#
#   Late Detraining Customers Avg Min Late mean  \
# 0                                        None
#
#    Total On Time Detraining Customers sum
# 0                               4107530.0

# %%
#hidden tests are within this cell

# %% [markdown]
# ### 3.3 _Pacific Surfliner_ trains [1 pt]
#
# Each _Pacific Surfliner_ train is identified by a unique train number. Create a `DataFrame` named `surf_trns` that contains one row for each train comprising the _Pacific Surfliner_ service. Include the following columns in the `DataFrame` in the order specified:
#
# 1. "Service Line"
# 2. "Service"
# 3. "Sub Service"
# 4. "Route Miles"
# 5. "Train Number"
#
# Reset the index (set `drop=True`) when creating the new `DataFrame`.

# %%
surf_trns = surf.drop_duplicates(subset='Train Number', ignore_index=True)
surf_trns = surf_trns[["Service Line", "Service", "Sub Service", "Route Miles", "Train Number"]]
surf_trns.head(3)
# Out:
#       Service Line            Service        Sub Service  Route Miles  \
# 0  State Supported  Pacific Surfliner  Pacific Surfliner          351
# 1  State Supported  Pacific Surfliner  Pacific Surfliner          351
# 2  State Supported  Pacific Surfliner  Pacific Surfliner          351
#
#    Train Number
# 0           562
# 1           564
# 2           572

# %%
#hidden tests are within this cell

# %% [markdown]
# ### 3.4 _Pacific Surfliner_: mean late arrival times summary statistics
#
# Review the central tendency, dispersion, and shape for the mean late arrival times of _Pacific Surfliner_ trains. Call the custom function named `frm.describe_numeric_column()` to return a dictionary of summary statistics.

# %%
# Drop missing values
surf_avg_mm_late = surf[COLS["late_detrn_avg_mm_late"]].dropna().reset_index(drop=True)

# Call the custom frm.describe_numeric_column() function again
surf_avg_mm_late_describe = frm.describe_numeric_column(surf_avg_mm_late)
surf_avg_mm_late_describe
# Out:
# {'type': pandas.core.series.Series,
#  'name': 'Late Detraining Customers Avg Min Late',
#  'values': {'non_null': np.int64(3774),
#   'missing': np.int64(0),
#   'dtype': dtype('float64')},
#  'center': {'mean': np.float64(42.63222045574987),
#   'median': 39.0,
#   'mode': np.float64(33.0)},
#  'position': {'min': 2.0,
#   '25%': np.float64(31.0),
#   '50%': np.float64(39.0),
#   '75%': np.float64(49.0),
#   'max': 391.0},
#  'spread': {'variance': 422.04811078520663,
#   'std': 20.543809548990826,
#   'range': 389.0,
#   'iqr': np.float64(18.0)},
#  'shape': {'skewness': np.float64(4.752313978802546),
#   'kurtosis': np.float64(54.5568427759855)}}

# %% [markdown]
# The skewness and kurtosis values returned suggest that the distribution of mean late arrival times of Pacific Surfliner trains is positively skewed and features a sharper peak and heavier right tail than a normal distribution. Let's confirm this visually by generating a histogram.

# %% [markdown]
# ### 3.5 _Pacific Surfliner_: visualize distribution of mean late arrival times: visualize distribution of mean late arrival times
#
# Visualize mean late arrival times for the entire period. The data is binned prior to plotting.
#
# #### 3.5.1 Create the chart data [1 pt]

# %%
# Convert to DataFrame
surf_avg_mm_late = surf_avg_mm_late.to_frame(name=COLS["avg_mm_late"])

# Get mean and standard deviation
mu = surf_avg_mm_late_describe["center"]["mean"]
sigma = surf_avg_mm_late_describe["spread"]["std"]

# Get max value (for x-axis ticks); pad max value for chart display
max_val = surf_avg_mm_late_describe["position"]["max"]
max_val_ceil = (np.ceil(max_val / 10) * 10).astype(int)

# Create bins
surf_mm_late, bins, num_bins, bin_width = frm.create_bins(surf_avg_mm_late, COLS["avg_mm_late"], 10)

# Bin the data
chrt_data = frm.bin_data(surf_mm_late, COLS["avg_mm_late"], bins)
# chrt_data

# %%
#hidden tests are within this cell

# %% [markdown]
# #### 3.5.2 Generate the histogram

# %%
# Chart title
title_txt = f"Amtrak {SUB_SVC['surf']} Service Late Detraining Passengers"
title = ttl.format_title(surf_stats, title_txt)

# Tooltips
tooltip_config = [
    {"shorthand": "bin_center:Q", "title": "Average Minutes Late", "format": None},
    {"shorthand": "count:Q", "title": "Late Arrivals Count", "format": None},
]

# Create and display the histogram
chart = hst.create_histogram(
    frame=chrt_data,
    x_shorthand="bin_center:Q",
    x_title="Average Minutes Late",
    y_shorthand="count:Q",
    y_title="Late Arrivals Count",
    y_stack=False,
    line_shorthand="Avg Min Late:Q",
    mu=mu,
    sigma=sigma,
    num_bins=num_bins,
    bin_width=bin_width,
    x_tick_count_max=max_val_ceil,
    bar_color=COLORS["amtk_blue"],
    mu_color=COLORS["amtk_red"],
    sigma_color=COLORS["anth_gray"],
    tooltip_config=tooltip_config,
    title=title,
)
chart.display()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### 3.6 _Pacific Surfliner_ Trains 774 & 777
#
# _Pacific Surfliner_ trains 774 (southbound) and 777 (northbound) operate Sunday to Friday between San Luis Obispo, CA ([SLO](https://www.amtrak.com/stations/slo)) and [Santa Fe Depot](https://www.amtrak.com/stations/san), San Diego, CA ([SAN](https://www.amtrak.com/stations/san)).
#
# #### 3.6.1 _Pacific Surfliner_ Train 774, southbound, detraining passengers summary statistics [1 pt]
#
# Departing Sunday to Friday from San Luis Obispo, CA ([SLO](https://www.amtrak.com/stations/slo)).

# %%
# YOUR CODE HERE
# Base columns for routes
rte_cols = [
    COLS["trn"],
    COLS["station_code"],
    COLS["station"],
    COLS["state"],
    COLS["lat"],
    COLS["lon"],
]

# Train 774 southbound
amtk_774 = ntwk.by_train_number(trains, 774)
amtk_774_rte = ntwk.create_route(amtk_774, TRN["774"]["direction"])
amtk_774_rte_stats = detrn.get_route_sum_stats(
    amtk_774_rte,
    COLS["station_code"],
    AGG["columns"],
    AGG["funcs"],
    rte_cols,
)
amtk_774_rte_stats.sort_values(by=[COLS["lat"]], ascending=False, inplace=True)

amtk_774_rte_stats
# Out:
#     Train Number Arrival Station Code        Arrival Station       State  \
# 0            774                  GVB           Grover Beach  California
# 1            774                  GUA  Guadalupe-Santa Maria  California
# 2            774                  LPS            Lompoc-Surf  California
# 3            774                  GTA                 Goleta  California
# 4            774                  SBA          Santa Barbara  California
# 5            774                  CPN            Carpinteria  California
# 6            774                  MPK               Moorpark  California
# 7            774                  VEC                Ventura  California
# 8            774                  SIM            Simi Valley  California
# 9            774                  CWT             Chatsworth  California
# 10           774                  CML              Camarillo  California
# 11           774                  VNC               Van Nuys  California
# 12           774                  OXN                 Oxnard  California
# 13           774                  BUR      Burbank (Airport)  California
# 14           774                  GDL               Glendale  California
# 15           774                  LAX            Los Angeles  California
# 16           774                  FUL              Fullerton  California
# 17           774                  ANA                Anaheim  California
# 18           774                  SNA              Santa Ana  California
# 19           774                  IRV                 Irvine  California
# 20           774                  SNC    San Juan Capistrano  California
# 21           774                  OSD              Oceanside  California
# 22           774                  SOL           Solana Beach  California
# 23           774                  OLT   San Diego (Old Town)  California
# 24           774                  SAN   San Diego (Downtown)  California
#
#      Latitude   Longitude  Train Arrivals  Total Detraining Customers sum  \
# 0   35.121260 -120.629266              12                             146
# 1   34.962927 -120.573410              10                              94
# 2   34.682704 -120.605001              12                             118
# 3   34.437729 -119.843092              12                            1729
# 4   34.413718 -119.692785              12                            8608
# 5   34.396780 -119.522975              12                            2929
# 6   34.284760 -118.878059              11                            1238
# 7   34.276929 -119.299918              12                            3773
# 8   34.270204 -118.695163              12                            1832
# 9   34.253205 -118.599417              12                            4994
# 10  34.215933 -119.034114              12                            2951
# 11  34.211294 -118.448206              12                            6440
# 12  34.199241 -119.175978              12                            2431
# 13  34.193072 -118.353767              12                           10233
# 14  34.123706 -118.258868              12                            7184
# 15  34.056177 -118.236778              12                           65442
# 16  33.868969 -117.922849              12                           19640
# 17  33.803803 -117.877308              12                           21747
# 18  33.751629 -117.856607              12                           13835
# 19  33.656771 -117.733695              12                           65297
# 20  33.501318 -117.663813              12                           16143
# 21  33.192515 -117.379430              11                           31241
# 22  32.992937 -117.271135              11                           30810
# 23  32.755266 -117.200073              11                           52669
# 24  32.716169 -117.169576              11                           90149
#
#     Total Detraining Customers mean  Total Detraining Customers median  \
# 0                           12.1667                                3.5
# 1                            9.4000                                6.0
# 2                            9.8333                                8.5
# 3                          144.0833                              151.0
# 4                          717.3333                              728.5
# 5                          244.0833                              241.5
# 6                          112.5455                              116.0
# 7                          314.4167                              287.5
# 8                          152.6667                              147.0
# 9                          416.1667                              393.0
# 10                         245.9167                              246.5
# 11                         536.6667                              543.5
# 12                         202.5833                              196.5
# 13                         852.7500                              871.0
# 14                         598.6667                              541.0
# 15                        5453.5000                             5254.5
# 16                        1636.6667                             1625.5
# 17                        1812.2500                             1910.5
# 18                        1152.9167                             1160.0
# 19                        5441.4167                             3056.0
# 20                        1345.2500                             1311.5
# 21                        2840.0909                             3330.0
# 22                        2800.9091                             3141.0
# 23                        4788.0909                             5297.0
# 24                        8195.3636                             9608.0
#
#     Total Detraining Customers std  Late Detraining Customers sum  \
# 0                          13.8356                              1
# 1                          11.5297                              1
# 2                           4.7832                             14
# 3                          43.4584                            500
# 4                         139.1751                           1806
# 5                          62.8005                            947
# 6                          47.0773                            251
# 7                         116.0975                            891
# 8                          33.9688                            423
# 9                         112.2836                           1213
# 10                         55.3673                            667
# 11                        128.6802                           1590
# 12                         46.3513                            629
# 13                        205.1758                           2445
# 14                        192.8967                           1841
# 15                       1532.7350                          12684
# 16                        329.8259                           3175
# 17                        359.5068                           3765
# 18                        193.2758                           2126
# 19                       4780.5223                           8313
# 20                        291.9586                           3781
# 21                       1385.7328                           7479
# 22                       1444.6562                           8723
# 23                       2339.0626                          16292
# 24                       4033.1456                          24570
#
#     Late Detraining Customers mean  Late Detraining Customers median  \
# 0                           0.0833                               0.0
# 1                           0.1000                               0.0
# 2                           1.1667                               1.0
# 3                          41.6667                              40.0
# 4                         150.5000                             140.5
# 5                          78.9167                              83.5
# 6                          22.8182                              17.0
# 7                          74.2500                              65.5
# 8                          35.2500                              28.0
# 9                         101.0833                              79.5
# 10                         55.5833                              46.0
# 11                        132.5000                             112.0
# 12                         52.4167                              41.0
# 13                        203.7500                             178.5
# 14                        153.4167                             121.5
# 15                       1057.0000                             975.0
# 16                        264.5833                             265.0
# 17                        313.7500                             316.5
# 18                        177.1667                             181.5
# 19                        692.7500                             458.5
# 20                        315.0833                             318.5
# 21                        679.9091                             746.0
# 22                        793.0000                             833.0
# 23                       1481.0909                            1712.0
# 24                       2233.6364                            2492.0
#
#     Late Detraining Customers std  Late to Total Detraining Customers Ratio  \
# 0                          0.2887                                    0.0068
# 1                          0.3162                                    0.0106
# 2                          1.1146                                    0.1186
# 3                         21.0641                                    0.2892
# 4                        102.3581                                    0.2098
# 5                         50.9393                                    0.3233
# 6                         20.2031                                    0.2027
# 7                         50.9637                                    0.2362
# 8                         19.7904                                    0.2309
# 9                         73.3676                                    0.2429
# 10                        40.6011                                    0.2260
# 11                        74.1430                                    0.2469
# 12                        41.3883                                    0.2587
# 13                       122.8807                                    0.2389
# 14                        81.0403                                    0.2563
# 15                       487.8010                                    0.1938
# 16                        61.4380                                    0.1617
# 17                        68.3309                                    0.1731
# 18                        43.1948                                    0.1537
# 19                       568.1008                                    0.1273
# 20                       105.3863                                    0.2342
# 21                       292.6518                                    0.2394
# 22                       358.7029                                    0.2831
# 23                       631.5363                                    0.3093
# 24                       921.0213                                    0.2725
#
#     Late Detraining Customers Avg Min Late mean  \
# 0                                       54.0000
# 1                                       22.0000
# 2                                       41.2500
# 3                                       28.3333
# 4                                       34.3333
# 5                                       29.0909
# 6                                       40.6364
# 7                                       32.5833
# 8                                       45.4167
# 9                                       40.9167
# 10                                      40.4167
# 11                                      43.1667
# 12                                      37.0833
# 13                                      42.7500
# 14                                      43.5833
# 15                                      44.0000
# 16                                      39.5833
# 17                                      39.5833
# 18                                      40.6667
# 19                                      42.0000
# 20                                      36.0833
# 21                                      39.0909
# 22                                      42.9091
# 23                                      44.0909
# 24                                      43.6364
#
#     Total On Time Detraining Customers sum
# 0                                      145
# 1                                       93
# 2                                      104
# 3                                     1229
# 4                                     6802
# 5                                     1982
# 6                                      987
# 7                                     2882
# 8                                     1409
# 9                                     3781
# 10                                    2284
# 11                                    4850
# 12                                    1802
# 13                                    7788
# 14                                    5343
# 15                                   52758
# 16                                   16465
# 17                                   17982
# 18                                   11709
# 19                                   56984
# 20                                   12362
# 21                                   23762
# 22                                   22087
# 23                                   36377
# 24                                   65579

# %%
#hidden tests are within this cell

# %% [markdown]
# ##### 3.6.1.1 Write to file [1 pt]
#
# Write `amtk_774_rte_stats` to a CSV file named `stu-amtk_774_rte_stats.csv`. Store the file in the `data/student` directory. Then compare it to the accompanying `fxt-amtk_774_rte_stats.csv` file. It must match line for line, character for character.

# %%
# YOUR CODE HERE
filepath = parent_path.joinpath("data", "student", "stu-amtk_774_rte_stats.csv")
amtk_774_rte_stats.to_csv(filepath, index=False)

# %%
#hidden tests are within this cell

# %% [markdown]
# #### 3.6.2 _Pacific Surfliner_ Train 774: late detraining metrics (fiscal year and quarter)
#
# Review the central tendency, dispersion, and shape for the mean late arrival times of _Pacific Surfliner_ Train 774. Call the custom function named `frm.describe_numeric_column()` to return a dictionary of summary statistics. Then visualize each fiscal year and quarter data with a box plot.

# %%
# Drop missing values
amtk_774_avg_mm_late = amtk_774[COLS["late_detrn_avg_mm_late"]].dropna().reset_index(drop=True)

# Describe the column
amtk_774_avg_mm_late_describe = frm.describe_numeric_column(amtk_774_avg_mm_late)
amtk_774_avg_mm_late_describe
# Out:
# {'type': pandas.core.series.Series,
#  'name': 'Late Detraining Customers Avg Min Late',
#  'values': {'non_null': np.int64(268),
#   'missing': np.int64(0),
#   'dtype': dtype('float64')},
#  'center': {'mean': np.float64(39.57462686567164),
#   'median': 37.0,
#   'mode': np.float64(37.0)},
#  'position': {'min': 18.0,
#   '25%': np.float64(32.0),
#   '50%': np.float64(37.0),
#   '75%': np.float64(45.0),
#   'max': 128.0},
#  'spread': {'variance': 147.5112639051932,
#   'std': 12.145421520276404,
#   'range': 110.0,
#   'iqr': np.float64(13.0)},
#  'shape': {'skewness': np.float64(2.541218278069484),
#   'kurtosis': np.float64(13.800652191508451)}}

# %% [markdown]
# ##### 3.6.2.1 Retrieve the chart data

# %%
# Base columns for average minutes late
cols = [COLS["year"], COLS["quarter"], COLS["late_detrn_avg_mm_late"]]

# Chart data
chrt_data = detrn.get_qtr_avg_min_late(
    amtk_774_rte, cols, COLS["year_quarter"], [COLORS["amtk_blue"], COLORS["amtk_red"]]
)
chrt_data
# Out:
#     Fiscal Year Quarter  Late Detraining Customers Avg Min Late    Color
# 0                2021Q4                                     NaN  #00537e
# 1                2021Q4                                    22.0  #00537e
# 2                2021Q4                                    25.0  #00537e
# 3                2021Q4                                    28.0  #00537e
# 4                2021Q4                                    30.0  #00537e
# ..                  ...                                     ...      ...
# 288              2024Q3                                    41.0  #ef3824
# 289              2024Q3                                    54.0  #ef3824
# 290              2024Q3                                    58.0  #ef3824
# 291              2024Q3                                    60.0  #ef3824
# 292              2024Q3                                    60.0  #ef3824
#
# [293 rows x 3 columns]

# %% [markdown]
# ##### 3.6.2.2 Preaggregate the data

# %%
# Base columns for aggregation statistics
cols = [COLS["year_quarter"], COLS["late_detrn_avg_mm_late"]]

# Pre-aggregate the data
chrt_data = frm.aggregate_data(chrt_data, cols)

# %% [markdown]
# ##### 3.6.2.3 Generate box plots

# %%
# Create chart title
txt = TRN["774"]
title_txt = (
    f"Amtrak {txt['name']} Train {txt['number']} Late Detraining Passengers\n"
    f"{txt['route']} ({txt['direction']})"
)
title = ttl.format_title(amtk_774_rte_stats, title_txt)

# Create and display the vertical boxplot
chart_vertical = boxp.create_boxplot(
    data=chrt_data,
    x_shorthand="Fiscal Year Quarter:N",
    x_title="Period",
    y_shorthand="Late Detraining Customers Avg Min Late:Q",
    y_title="Average Minutes Late",
    box_size=20,
    outlier_shorthand="outliers:Q",
    color_shorthand="Color:N",
    chart_title=title,
    orient=boxp.Orient.VERTICAL,
)
chart_vertical.display()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# #### 3.6.3 _Pacific Surfliner_ Train 777, westbound, detraining passengers summary statistics [1 pt]
#
# Departs Sunday to Friday from [Santa Fe Depot](https://www.amtrak.com/stations/san), San Diego, CA ([SAN](https://www.amtrak.com/stations/san)).
#
# Review previous code employed to generate summary statistics for an Amtrak train. Then leverage functions available in the `amtk_network` and `amtk_detrain` modules to create three new `DataFrame` objects named `amtk_777`, `amtk_777_rte`, and `amtk_777_rte_stats`, respectively.

# %%
# YOUR CODE HERE
# Base columns for routes
rte_cols = [
    COLS["trn"],
    COLS["station_code"],
    COLS["station"],
    COLS["state"],
    COLS["lat"],
    COLS["lon"],
]

# Train 774 southbound
amtk_777 = ntwk.by_train_number(trains, 777)
amtk_777_rte = ntwk.create_route(amtk_777, TRN["777"]["direction"])
amtk_777_rte_stats = detrn.get_route_sum_stats(
    amtk_777_rte,
    COLS["station_code"],
    AGG["columns"],
    AGG["funcs"],
    rte_cols,
)
amtk_777_rte_stats.sort_values(by=[COLS["lat"]], ascending=True, inplace=True)

amtk_777_rte_stats
# Out:
#     Train Number Arrival Station Code        Arrival Station       State  \
# 0            777                  OLT   San Diego (Old Town)  California
# 1            777                  SOL           Solana Beach  California
# 2            777                  OSD              Oceanside  California
# 3            777                  SNC    San Juan Capistrano  California
# 4            777                  IRV                 Irvine  California
# 5            777                  SNA              Santa Ana  California
# 6            777                  ANA                Anaheim  California
# 7            777                  FUL              Fullerton  California
# 8            777                  LAX            Los Angeles  California
# 9            777                  GDL               Glendale  California
# 10           777                  BBK                Burbank  California
# 11           777                  BUR      Burbank (Airport)  California
# 12           777                  OXN                 Oxnard  California
# 13           777                  VNC               Van Nuys  California
# 14           777                  CML              Camarillo  California
# 15           777                  NRG     Northridge Station  California
# 16           777                  CWT             Chatsworth  California
# 17           777                  SIM            Simi Valley  California
# 18           777                  VEC                Ventura  California
# 19           777                  MPK               Moorpark  California
# 20           777                  CPN            Carpinteria  California
# 21           777                  SBA          Santa Barbara  California
# 22           777                  GTA                 Goleta  California
# 23           777                  LPS            Lompoc-Surf  California
# 24           777                  GUA  Guadalupe-Santa Maria  California
# 25           777                  GVB           Grover Beach  California
# 26           777                  SLO        San Luis Obispo  California
#
#      Latitude   Longitude  Train Arrivals  Total Detraining Customers sum  \
# 0   32.755266 -117.200073              11                             344
# 1   32.992937 -117.271135              11                            2227
# 2   33.192515 -117.379430              11                            4740
# 3   33.501318 -117.663813              11                           11642
# 4   33.656771 -117.733695              12                           14275
# 5   33.751629 -117.856607              12                            9223
# 6   33.803803 -117.877308              12                           20234
# 7   33.868969 -117.922849              12                           17801
# 8   34.056177 -118.236778              12                          128371
# 9   34.123706 -118.258868              12                            9433
# 10  34.171299 -118.299900               9                            3995
# 11  34.193072 -118.353767              12                           10872
# 12  34.199241 -119.175978              12                           36152
# 13  34.211294 -118.448206              12                           13447
# 14  34.215933 -119.034114              12                           17517
# 15  34.230659 -118.545417               9                            5442
# 16  34.253205 -118.599417              12                           13023
# 17  34.270204 -118.695163              12                           13420
# 18  34.276929 -119.299918              12                           19928
# 19  34.284760 -118.878059              11                            9213
# 20  34.396780 -119.522975              12                            5647
# 21  34.413718 -119.692785              12                           56705
# 22  34.437729 -119.843092              12                           27787
# 23  34.682704 -120.605001              12                            7329
# 24  34.962927 -120.573410              12                            9771
# 25  35.121260 -120.629266              12                           10826
# 26  35.276434 -120.654701              12                           35116
#
#     Total Detraining Customers mean  Total Detraining Customers median  \
# 0                           31.2727                               37.0
# 1                          202.4545                              185.0
# 2                          430.9091                              456.0
# 3                         1058.3636                             1186.0
# 4                         1189.5833                             1382.5
# 5                          768.5833                              819.5
# 6                         1686.1667                             1513.5
# 7                         1483.4167                             1488.0
# 8                        10697.5833                            10209.0
# 9                          786.0833                              724.0
# 10                         443.8889                              420.0
# 11                         906.0000                              936.5
# 12                        3012.6667                             3269.0
# 13                        1120.5833                             1127.0
# 14                        1459.7500                             1583.5
# 15                         604.6667                              658.0
# 16                        1085.2500                             1017.0
# 17                        1118.3333                             1170.0
# 18                        1660.6667                             1717.0
# 19                         837.5455                              870.0
# 20                         470.5833                              470.5
# 21                        4725.4167                             4599.0
# 22                        2315.5833                             2397.5
# 23                         610.7500                              619.0
# 24                         814.2500                              831.5
# 25                         902.1667                              957.0
# 26                        2926.3333                             2937.5
#
#     Total Detraining Customers std  Late Detraining Customers sum  \
# 0                          19.9253                              5
# 1                         143.0569                             23
# 2                         163.0751                            138
# 3                         437.4074                            900
# 4                         584.7832                           1080
# 5                         272.3101                            760
# 6                         550.7651                           1781
# 7                         214.2112                           1801
# 8                        1638.2428                          11042
# 9                         263.4117                           1161
# 10                        160.6444                            307
# 11                        232.6433                           1112
# 12                        826.2681                           6504
# 13                        199.4485                           1330
# 14                        354.5935                           2838
# 15                        226.4095                            820
# 16                        208.1333                           1911
# 17                        174.3196                           1991
# 18                        290.1819                           5385
# 19                        252.1905                           1574
# 20                         70.8551                           1771
# 21                        572.7761                          20875
# 22                        463.7449                          11239
# 23                        126.9647                           4837
# 24                        147.6976                           6963
# 25                        182.4559                           7945
# 26                        456.7502                          18891
#
#     Late Detraining Customers mean  Late Detraining Customers median  \
# 0                           0.4545                               0.0
# 1                           2.0909                               1.0
# 2                          12.5455                              12.0
# 3                          81.8182                              62.0
# 4                          90.0000                              78.5
# 5                          63.3333                              51.0
# 6                         148.4167                             130.5
# 7                         150.0833                             150.0
# 8                         920.1667                             828.0
# 9                          96.7500                              72.0
# 10                         34.1111                              40.0
# 11                         92.6667                              91.0
# 12                        542.0000                             517.5
# 13                        110.8333                             107.0
# 14                        236.5000                             231.0
# 15                         91.1111                              97.0
# 16                        159.2500                             141.0
# 17                        165.9167                             177.0
# 18                        448.7500                             404.0
# 19                        143.0909                             136.0
# 20                        147.5833                             109.5
# 21                       1739.5833                            1759.5
# 22                        936.5833                            1032.5
# 23                        403.0833                             408.0
# 24                        580.2500                             541.5
# 25                        662.0833                             635.5
# 26                       1574.2500                            1566.0
#
#     Late Detraining Customers std  Late to Total Detraining Customers Ratio  \
# 0                          0.8202                                    0.0145
# 1                          2.9139                                    0.0103
# 2                         11.8858                                    0.0291
# 3                         69.2717                                    0.0773
# 4                         70.7377                                    0.0757
# 5                         44.7667                                    0.0824
# 6                         80.1322                                    0.0880
# 7                         66.3057                                    0.1012
# 8                        324.0058                                    0.0860
# 9                        112.2636                                    0.1231
# 10                        14.8361                                    0.0768
# 11                        31.6180                                    0.1023
# 12                       257.5863                                    0.1799
# 13                        45.2123                                    0.0989
# 14                       114.2457                                    0.1620
# 15                        47.1074                                    0.1507
# 16                        57.9484                                    0.1467
# 17                        49.9408                                    0.1484
# 18                       282.8225                                    0.2702
# 19                        50.6388                                    0.1708
# 20                        94.9846                                    0.3136
# 21                      1098.3767                                    0.3681
# 22                       397.1790                                    0.4045
# 23                       147.6682                                    0.6600
# 24                       174.3581                                    0.7126
# 25                       215.8789                                    0.7339
# 26                       569.8060                                    0.5380
#
#     Late Detraining Customers Avg Min Late mean  \
# 0                                       29.6667
# 1                                       40.1667
# 2                                       48.5556
# 3                                       53.4000
# 4                                       55.4545
# 5                                       51.0000
# 6                                       51.5833
# 7                                       44.5833
# 8                                       56.0833
# 9                                       57.5833
# 10                                      56.2222
# 11                                      52.9167
# 12                                      46.3333
# 13                                      54.2500
# 14                                      46.2500
# 15                                      39.2222
# 16                                      45.7500
# 17                                      45.5000
# 18                                      45.0000
# 19                                      50.5455
# 20                                      49.0000
# 21                                      49.1667
# 22                                      46.3333
# 23                                      45.7500
# 24                                      49.5000
# 25                                      50.1667
# 26                                      47.9167
#
#     Total On Time Detraining Customers sum
# 0                                      339
# 1                                     2204
# 2                                     4602
# 3                                    10742
# 4                                    13195
# 5                                     8463
# 6                                    18453
# 7                                    16000
# 8                                   117329
# 9                                     8272
# 10                                    3688
# 11                                    9760
# 12                                   29648
# 13                                   12117
# 14                                   14679
# 15                                    4622
# 16                                   11112
# 17                                   11429
# 18                                   14543
# 19                                    7639
# 20                                    3876
# 21                                   35830
# 22                                   16548
# 23                                    2492
# 24                                    2808
# 25                                    2881
# 26                                   16225

# %%
#hidden tests are within this cell

# %% [markdown]
# ##### 3.6.3.1 Write to file [1 pt]
#
# Write `amtk_777_rte_stats` to a CSV file named `stu-amtk_777_rte_stats.csv`. Store the file in the `data/student` directory. Then compare it to the accompanying `fxt-amtk_777_rte_stats.csv` file. It must match line for line, character for character.

# %%
# YOUR CODE HERE
filepath = parent_path.joinpath("data", "student", "stu-amtk_777_rte_stats.csv")
amtk_777_rte_stats.to_csv(filepath, index=False)

# %%
#hidden tests are within this cell

# %% [markdown]
# #### 3.6.4 _Pacific Surfliner_ Train 777: late detraining metrics (fiscal year and quarter) [1 pt]
#
# Review the central tendency, dispersion, and shape for the mean late arrival times of _Pacific Surfliner_ Train 777. Call the custom function named `frm.describe_numeric_column()` to return a dictionary of summary statistics. Then visualize each fiscal year and quarter data with a box plot.

# %%
# Drop missing values
amtk_777_avg_mm_late = amtk_777[COLS["late_detrn_avg_mm_late"]].dropna().reset_index(drop=True)

# Describe the column
amtk_777_avg_mm_late_describe = frm.describe_numeric_column(amtk_777_avg_mm_late)
amtk_777_avg_mm_late_describe
# Out:
# {'type': pandas.core.series.Series,
#  'name': 'Late Detraining Customers Avg Min Late',
#  'values': {'non_null': np.int64(296),
#   'missing': np.int64(0),
#   'dtype': dtype('float64')},
#  'center': {'mean': np.float64(49.12837837837838),
#   'median': 45.0,
#   'mode': np.float64(40.0)},
#  'position': {'min': 17.0,
#   '25%': np.float64(37.0),
#   '50%': np.float64(45.0),
#   '75%': np.float64(56.25),
#   'max': 137.0},
#  'spread': {'variance': 349.14956481905637,
#   'std': 18.68554427409211,
#   'range': 120.0,
#   'iqr': np.float64(19.25)},
#  'shape': {'skewness': np.float64(1.772095312174482),
#   'kurtosis': np.float64(4.790974152163351)}}

# %%
#hidden tests are within this cell

# %% [markdown]
# ##### 3.6.4.1 Retrieve the chart data

# %%
# Base columns for average minutes late
cols = [COLS["year"], COLS["quarter"], COLS["late_detrn_avg_mm_late"]]

# Chart data
chrt_data = detrn.get_qtr_avg_min_late(
    amtk_777_rte, cols, COLS["year_quarter"], [COLORS["amtk_blue"], COLORS["amtk_red"]]
)
# chrt_data

# %% [markdown]
# ##### 3.6.4.2 Preaggregate the data

# %%
# Base columns for aggregation statistics
cols = [COLS["year_quarter"], COLS["late_detrn_avg_mm_late"]]

# Pre-aggregate the data
chrt_data = frm.aggregate_data(chrt_data, cols)

# %% [markdown]
# ##### 3.6.4.3 Generate box plots
#
# Visualize the distribution of mean late arrival times for late detraining passengers. Illustrate with box plots.

# %%
# Create chart title
txt = TRN["777"]
title_txt = (
    f"Amtrak {txt['name']} Train {txt['number']} Late Detraining Passengers\n"
    f"{txt['route']} ({txt['direction']})"
)
title = ttl.format_title(amtk_777_rte_stats, title_txt)

# Create and display the vertical boxplot
chart_vertical = boxp.create_boxplot(
    data=chrt_data,
    x_shorthand="Fiscal Year Quarter:N",
    x_title="Period",
    y_shorthand="Late Detraining Customers Avg Min Late:Q",
    y_title="Average Minutes Late",
    box_size=20,
    outlier_shorthand="outliers:Q",
    color_shorthand="Color:N",
    chart_title=title,
    orient=boxp.Orient.VERTICAL,
)
chart_vertical.display()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## 4.0 Long-distance trains
#
# Amtrak's long-distance trains operate across the United States. These trains are typically overnight services that connect major cities and regions. Long-distance trains are known for their scenic routes and dining car services.
#
# ### 4.1 _City of New Orleans_ service (Chicago - Memphis - New Orleans) [1 pt]
#
# The [_City of New Orleans_](https://www.amtrak.com/city-of-new-orleans-train), operates daily between [Chicago Union Station](https://www.amtrak.com/stations/chi), Chicago, IL ([CHI](https://www.amtrak.com/stations/chi)) and [Union Passenger Terminal](https://www.amtrak.com/stations/NOL), New Orleans, LA ([NOL](https://www.amtrak.com/stations/NOL)) via [Central Station](https://www.amtrak.com/stations/mem), Memphis, TN ([MEM](https://www.amtrak.com/stations/mem)). The train revives the name of the Illinois Central Railroad's [_City of New Orleans_](https://en.wikipedia.org/wiki/City_of_New_Orleans_(train)) that operated between 1947 and 1971. The train is also known for its association with the classic tune [\"City of New Orleans\"](https://en.wikipedia.org/wiki/City_of_New_Orleans_(song)) written by Steve Goodman and popularized by Arlo Guthrie.
#
# Retrieve the _City of New Orleans_ performance data by calling the appropriate `amtk_network` function. Assign the return value of the function call to a variable named `cno`.

# %%
trains
# Out:
#        Fiscal Year  Fiscal Quarter     Service Line            Service  \
# 0             2024               3    Long Distance         Auto Train
# 1             2024               3    Long Distance         Auto Train
# 2             2024               3    Long Distance  California Zephyr
# 3             2024               3    Long Distance  California Zephyr
# 4             2024               3    Long Distance  California Zephyr
# ...            ...             ...              ...                ...
# 68407         2021               4  State Supported          Vermonter
# 68408         2021               4  State Supported          Vermonter
# 68409         2021               4  State Supported          Vermonter
# 68410         2021               4  State Supported          Vermonter
# 68411         2021               4  State Supported          Vermonter
#
#              Sub Service  Route Miles  Train Number Arrival Station Code  \
# 0             Auto Train          914            52                  LOR
# 1             Auto Train          914            53                  SFA
# 2      California Zephyr         2408             5                  BRL
# 3      California Zephyr         2408             5                  COX
# 4      California Zephyr         2408             5                  CRN
# ...                  ...          ...           ...                  ...
# 68407          Vermonter          602            57                  WAS
# 68408          Vermonter          602            57                  WIL
# 68409          Vermonter          602            57                  WNL
# 68410          Vermonter          602            57                  WNM
# 68411          Vermonter          602            57                  WRJ
#
#             Arrival Station                  Arrival Station Type  ...  \
# 0       Lorton (Auto Train)  Station Building (with waiting room)  ...
# 1      Sanford (Auto Train)  Station Building (with waiting room)  ...
# 2                Burlington  Station Building (with waiting room)  ...
# 3                    Colfax  Station Building (with waiting room)  ...
# 4                   Creston  Station Building (with waiting room)  ...
# ...                     ...                                   ...  ...
# 68407            Washington  Station Building (with waiting room)  ...
# 68408            Wilmington  Station Building (with waiting room)  ...
# 68409         Windsor Locks                 Platform with Shelter  ...
# 68410               Windsor            Platform only (no shelter)  ...
# 68411  White River Junction  Station Building (with waiting room)  ...
#
#                       State            Division     Region        Country  \
# 0                  Virginia      South Atlantic      South  United States
# 1                   Florida      South Atlantic      South  United States
# 2                      Iowa  West North Central    Midwest  United States
# 3                California             Pacific       West  United States
# 4                      Iowa  West North Central    Midwest  United States
# ...                     ...                 ...        ...            ...
# 68407  District of Columbia      South Atlantic      South  United States
# 68408              Delaware      South Atlantic      South  United States
# 68409           Connecticut         New England  Northeast  United States
# 68410               Vermont         New England  Northeast  United States
# 68411               Vermont         New England  Northeast  United States
#
#         Latitude   Longitude Total Detraining Customers  \
# 0      38.708143  -77.220942                      42445
# 1      28.808544  -81.291274                      28034
# 2      40.805788  -91.101951                        557
# 3      39.099172 -120.953075                        508
# 4      41.056920  -94.361617                        205
# ...          ...         ...                        ...
# 68407  38.896993  -77.006422                       5191
# 68408  39.737263  -75.551095                        464
# 68409  41.913956  -72.626101                         21
# 68410  43.479908  -72.384985                         14
# 68411  43.647785  -72.317272                         61
#
#       Late Detraining Customers  Late to Total Detraining Customers Ratio  \
# 0                         23316                                   0.54932
# 1                         18439                                   0.65774
# 2                           223                                   0.40036
# 3                           326                                   0.64173
# 4                           144                                   0.70244
# ...                         ...                                       ...
# 68407                       187                                   0.03602
# 68408                        45                                   0.09698
# 68409                        12                                   0.57143
# 68410                        10                                   0.71429
# 68411                        19                                   0.31148
#
#        Late Detraining Customers Avg Min Late
# 0                                        95.0
# 1                                        91.0
# 2                                        54.0
# 3                                        99.0
# 4                                        67.0
# ...                                       ...
# 68407                                    37.0
# 68408                                    28.0
# 68409                                    35.0
# 68410                                    26.0
# 68411                                    27.0
#
# [68412 rows x 24 columns]

# %%
cno = ntwk.by_sub_service(trains, "City Of New Orleans")
cno
# Out:
#      Fiscal Year  Fiscal Quarter   Service Line              Service  \
# 0           2024               3  Long Distance  City Of New Orleans
# 1           2024               3  Long Distance  City Of New Orleans
# 2           2024               3  Long Distance  City Of New Orleans
# 3           2024               3  Long Distance  City Of New Orleans
# 4           2024               3  Long Distance  City Of New Orleans
# ..           ...             ...            ...                  ...
# 531         2022               1  Long Distance  City Of New Orleans
# 532         2022               1  Long Distance  City Of New Orleans
# 533         2022               1  Long Distance  City Of New Orleans
# 534         2022               1  Long Distance  City Of New Orleans
# 535         2022               1  Long Distance  City Of New Orleans
#
#              Sub Service  Route Miles  Train Number Arrival Station Code  \
# 0    City Of New Orleans          930            58                  BRH
# 1    City Of New Orleans          930            58                  CDL
# 2    City Of New Orleans          930            58                  CEN
# 3    City Of New Orleans          930            58                  CHI
# 4    City Of New Orleans          930            58                  CHM
# ..                   ...          ...           ...                  ...
# 531  City Of New Orleans          930            59                  MEM
# 532  City Of New Orleans          930            59                  MKS
# 533  City Of New Orleans          930            59                  NBN
# 534  City Of New Orleans          930            59                  NOL
# 535  City Of New Orleans          930            59                  YAZ
#
#              Arrival Station                  Arrival Station Type  ...  \
# 0                 Brookhaven  Station Building (with waiting room)  ...
# 1        Carbondale (Amtrak)  Station Building (with waiting room)  ...
# 2                  Centralia  Station Building (with waiting room)  ...
# 3    Chicago (Union Station)  Station Building (with waiting room)  ...
# 4           Champaign-Urbana  Station Building (with waiting room)  ...
# ..                       ...                                   ...  ...
# 531                  Memphis  Station Building (with waiting room)  ...
# 532                    Marks                 Platform with Shelter  ...
# 533        Newbern-Dyersburg  Station Building (with waiting room)  ...
# 534              New Orleans  Station Building (with waiting room)  ...
# 535               Yazoo City                 Platform with Shelter  ...
#
#            State            Division   Region        Country   Latitude  \
# 0    Mississippi  East South Central    South  United States  31.582961
# 1       Illinois  East North Central  Midwest  United States  37.724235
# 2       Illinois  East North Central  Midwest  United States  38.527531
# 3       Illinois  East North Central  Midwest  United States  41.878992
# 4       Illinois  East North Central  Midwest  United States  40.115843
# ..           ...                 ...      ...            ...        ...
# 531    Tennessee  East South Central    South  United States  35.132458
# 532  Mississippi  East South Central    South  United States  34.258227
# 533    Tennessee  East South Central    South  United States  36.112711
# 534    Louisiana  West South Central    South  United States  29.946085
# 535  Mississippi  East South Central    South  United States  32.848477
#
#      Longitude Total Detraining Customers Late Detraining Customers  \
# 0   -90.441070                        166                       108
# 1   -89.216628                        857                       170
# 2   -89.136118                         84                        32
# 3   -87.641015                      16591                      2365
# 4   -88.241366                       1159                       532
# ..         ...                        ...                       ...
# 531 -90.059109                       2294                       324
# 532 -90.272342                        191                        54
# 533 -89.262264                        239                       125
# 534 -90.078291                       6351                       721
# 535 -90.415230                        263                       122
#
#      Late to Total Detraining Customers Ratio  \
# 0                                     0.65060
# 1                                     0.19837
# 2                                     0.38095
# 3                                     0.14255
# 4                                     0.45902
# ..                                        ...
# 531                                   0.14124
# 532                                   0.28272
# 533                                   0.52301
# 534                                   0.11353
# 535                                   0.46388
#
#      Late Detraining Customers Avg Min Late
# 0                                      37.0
# 1                                     126.0
# 2                                      52.0
# 3                                     145.0
# 4                                      88.0
# ..                                      ...
# 531                                   127.0
# 532                                    62.0
# 533                                    78.0
# 534                                   167.0
# 535                                    93.0
#
# [536 rows x 24 columns]

# %%
#hidden tests are within this cell

# %% [markdown]
# ### 4.2 _City of New Orleans_: on-time performance metrics (entire period)
#
# _City of New Orleans_ performance data is a compilation of quarterly metrics that focus on late
# detraining passengers. Detraining assengers are considered on-time if they arrive at their
# destination no later than fifteen (`15`) minutes after their scheduled arrival time. All other
# detraining passengers are considered late.

# %%
# Total train arrivals
cno_trn_arrivals = cno.shape[0]

# Detraining totals
cno_detrn = cno[COLS["total_detrn"]].sum()
cno_detrn_late = cno[COLS["late_detrn"]].sum()
cno_detrn_on_time = cno_detrn - cno_detrn_late

print(
    f"Train Arrivals: {cno_trn_arrivals}",
    f"Total Detraining Customers: {cno_detrn}",
    f"Late Detraining Customers: {cno_detrn_late}",
    f"On-Time Detraining Customers: {cno_detrn_on_time}",
    sep="\n",
)

# Compute summary statistics
cno_stats = detrn.get_sum_stats(cno, AGG["columns"], AGG["funcs"])
cno_stats
# Out:
# Train Arrivals: 536
# Total Detraining Customers: 570194
# Late Detraining Customers: 159831
# On-Time Detraining Customers: 410363
#    Train Arrivals  Total Detraining Customers sum  \
# 0             536                        570194.0
#
#    Total Detraining Customers mean  Total Detraining Customers median  \
# 0                        1063.7948                              212.5
#
#    Total Detraining Customers std  Late Detraining Customers sum  \
# 0                       2503.7947                       159831.0
#
#    Late Detraining Customers mean  Late Detraining Customers median  \
# 0                        298.1922                              95.5
#
#    Late Detraining Customers std  Late to Total Detraining Customers Ratio  \
# 0                       605.9606                                    0.2803
#
#   Late Detraining Customers Avg Min Late mean  \
# 0                                        None
#
#    Total On Time Detraining Customers sum
# 0                                410363.0

# %% [markdown]
# ### 4.3 _City of New Orleans_ trains [1 pt]
#
# Each _City of New Orleans_ train is identified by a unique train number.
#
# Create a `DataFrame` named `cno_trns` that contains one row for each train comprising the _City of New Orleans_ service. Include the following columns in the `DataFrame` in the order specified:
#
# 1. "Service Line"
# 2. "Service"
# 3. "Sub Service"
# 4. "Route Miles"
# 5. "Train Number"
#
# Reset the index (set `drop=True`) when creating the new `DataFrame`

# %%
cno_trns = cno.drop_duplicates(subset='Train Number', ignore_index=True)
cno_trns = cno_trns[["Service Line", "Service", "Sub Service", "Route Miles", "Train Number"]]
cno_trns.head(3)
# Out:
#     Service Line              Service          Sub Service  Route Miles  \
# 0  Long Distance  City Of New Orleans  City Of New Orleans          930
# 1  Long Distance  City Of New Orleans  City Of New Orleans          930
# 2  Long Distance  City Of New Orleans  City Of New Orleans          930
#
#    Train Number
# 0            58
# 1            59
# 2          1058

# %%
#hidden tests are within this cell

# %% [markdown]
# ### 4.4 _City of New Orleans_: mean late arrival times summary statistics
#
# Review the central tendency, dispersion, and shape for the mean late arrival times of _City of New Orleans_ trains. Call the custom function named `frm.describe_numeric_column()` to return a dictionary of summary statistics.

# %%
# Drop missing values
cno_avg_mm_late = cno[COLS["late_detrn_avg_mm_late"]].dropna().reset_index(drop=True)

# Call the custom frm.describe_numeric_column() function again
cno_avg_mm_late_describe = frm.describe_numeric_column(cno_avg_mm_late)
cno_avg_mm_late_describe
# Out:
# {'type': pandas.core.series.Series,
#  'name': 'Late Detraining Customers Avg Min Late',
#  'values': {'non_null': np.int64(493),
#   'missing': np.int64(0),
#   'dtype': dtype('float64')},
#  'center': {'mean': np.float64(71.50101419878297),
#   'median': 68.0,
#   'mode': np.float64(68.0)},
#  'position': {'min': 18.0,
#   '25%': np.float64(51.0),
#   '50%': np.float64(68.0),
#   '75%': np.float64(85.0),
#   'max': 387.0},
#  'spread': {'variance': 1251.2423770180908,
#   'std': 35.372904560102086,
#   'range': 369.0,
#   'iqr': np.float64(34.0)},
#  'shape': {'skewness': np.float64(2.54874272793014),
#   'kurtosis': np.float64(15.515159904674796)}}

# %% [markdown]
# The skewness and kurtosis values returned suggest that the distribution of mean late arrival times of _City of New Orleans_ trains is positively skewed and features a sharper peak and heavier right tail than a normal distribution. Let's confirm this visually by generating a histogram.

# %% [markdown]
# ### 4.5 _City of New Orleans_: visualize distribution of mean late arrival times
#
# Visualize mean late arrival times for the entire period. The data is binned prior to plotting.
#
# #### 4.5.1 Create the chart data

# %%
# Convert to DataFrame
cno_avg_mm_late = cno_avg_mm_late.to_frame(name=COLS["avg_mm_late"])

# Get mean and standard deviation
mu = cno_avg_mm_late_describe["center"]["mean"]
sigma = cno_avg_mm_late_describe["spread"]["std"]

# Get max value (for x-axis ticks); pad max value for chart display
max_val = cno_avg_mm_late_describe["position"]["max"]
max_val_ceil = (np.ceil(max_val / 10) * 10).astype(int)

# Create bins
cno_mm_late, bins, num_bins, bin_width = frm.create_bins(cno_avg_mm_late, COLS["avg_mm_late"], 10)

# Bin the data
chrt_data = frm.bin_data(cno_mm_late, COLS["avg_mm_late"], bins)
# chrt_data

# %% [markdown]
# #### 4.5.2 Generate the histogram

# %%
# Chart title
title_txt = f"Amtrak {SUB_SVC['cno']} Service Late Detraining Passengers"
title = ttl.format_title(cno_stats, title_txt)

# Tooltips
tooltip_config = [
    {"shorthand": "bin_center:Q", "title": "Average Minutes Late", "format": None},
    {"shorthand": "count:Q", "title": "Late Arrivals Count", "format": None},
]

chart = hst.create_histogram(
    frame=chrt_data,
    x_shorthand="bin_center:Q",
    x_title="Average Minutes Late",
    y_shorthand="count:Q",
    y_title="Late Arrivals Count",
    y_stack=False,
    line_shorthand="Avg Min Late:Q",
    mu=mu,
    sigma=sigma,
    num_bins=num_bins,
    bin_width=bin_width,
    x_tick_count_max=max_val_ceil,
    bar_color=COLORS["amtk_blue"],
    mu_color=COLORS["amtk_red"],
    sigma_color=COLORS["anth_gray"],
    tooltip_config=tooltip_config,
    title=title,
)
chart.display()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### 4.6 _City of New Orleans_, Train 59 and 58
#
# City of New Orleans trains 59 (southbound) and 58 (northbound) operate daily between [Chicago Union Station](https://www.amtrak.com/stations/chi), Chicago, IL ([CHI](https://www.amtrak.com/stations/chi)) and [Union Passenger Terminal](https://www.amtrak.com/stations/NOL), New Orleans, LA ([NOL](https://www.amtrak.com/stations/NOL)).
#
# #### 4.6.1 _City of New Orleans_ Train 59, southbound, detraining passengers summary statistics [1 pt]
#
# Departs daily from [Chicago Union Station](https://www.amtrak.com/stations/chi), Chicago, IL ([CHI](https://www.amtrak.com/stations/chi)).

# %%
# Base columns for routes
rte_cols = [COLS["trn"], COLS["station_code"], COLS["station"], COLS["state"], COLS["lat"], COLS["lon"]]

# Train 59 southbound
amtk_59 = ntwk.by_train_number(trains, 59)
amtk_59_rte = ntwk.create_route(amtk_59, "southbound")
amtk_59_rte_stats = detrn.get_route_sum_stats(
    amtk_59_rte, COLS["station_code"], AGG["columns"], AGG["funcs"], rte_cols
)
amtk_59_rte_stats
# Out:
#     Train Number Arrival Station Code      Arrival Station        State  \
# 0             59                  HMW             Homewood     Illinois
# 1             59                  KKI             Kankakee     Illinois
# 2             59                  CHM     Champaign-Urbana     Illinois
# 3             59                  MAT              Mattoon     Illinois
# 4             59                  EFG            Effingham     Illinois
# 5             59                  CEN            Centralia     Illinois
# 6             59                  CDL  Carbondale (Amtrak)     Illinois
# 7             59                  FTN               Fulton     Kentucky
# 8             59                  NBN    Newbern-Dyersburg    Tennessee
# 9             59                  MEM              Memphis    Tennessee
# 10            59                  MKS                Marks  Mississippi
# 11            59                  GWD            Greenwood  Mississippi
# 12            59                  YAZ           Yazoo City  Mississippi
# 13            59                  JAN              Jackson  Mississippi
# 14            59                  HAZ           Hazlehurst  Mississippi
# 15            59                  BRH           Brookhaven  Mississippi
# 16            59                  MCB               McComb  Mississippi
# 17            59                  HMD              Hammond    Louisiana
# 18            59                  NOL          New Orleans    Louisiana
#
#      Latitude  Longitude  Train Arrivals  Total Detraining Customers sum  \
# 0   41.562446 -87.668685              11                             469
# 1   41.119259 -87.865430              11                            2392
# 2   40.115843 -88.241366              11                           54699
# 3   39.482730 -88.376045              11                            7434
# 4   39.117059 -88.547110              11                            3548
# 5   38.527531 -89.136118              11                            2435
# 6   37.724235 -89.216628              11                           15294
# 7   36.525704 -88.888772              11                            3159
# 8   36.112711 -89.262264              11                            3105
# 9   35.132458 -90.059109              11                           31894
# 10  34.258227 -90.272342              11                            2670
# 11  33.517159 -90.176454              11                           12476
# 12  32.848477 -90.415230              11                            3284
# 13  32.300808 -90.190936              11                           25054
# 14  31.861320 -90.394347              11                             959
# 15  31.582961 -90.441070              11                            3117
# 16  31.244467 -90.451334              11                            3358
# 17  30.507180 -90.462169              11                            9558
# 18  29.946085 -90.078291              11                          104438
#
#     Total Detraining Customers mean  Total Detraining Customers median  \
# 0                           42.6364                               44.0
# 1                          217.4545                              220.0
# 2                         4972.6364                             4972.0
# 3                          675.8182                              675.0
# 4                          322.5455                              333.0
# 5                          221.3636                              215.0
# 6                         1390.3636                             1421.0
# 7                          287.1818                              281.0
# 8                          282.2727                              258.0
# 9                         2899.4545                             2749.0
# 10                         242.7273                              209.0
# 11                        1134.1818                             1097.0
# 12                         298.5455                              280.0
# 13                        2277.6364                             2188.0
# 14                          87.1818                               77.0
# 15                         283.3636                              277.0
# 16                         305.2727                              312.0
# 17                         868.9091                              812.0
# 18                        9494.3636                            10549.0
#
#     Total Detraining Customers std  Late Detraining Customers sum  \
# 0                          18.0902                             86
# 1                          48.9374                            583
# 2                         960.7651                          14149
# 3                         236.6866                           2722
# 4                         111.2622                           1397
# 5                          81.8099                           1074
# 6                         442.8492                           5902
# 7                         104.7720                           1920
# 8                          70.9804                           1775
# 9                         790.1422                           6495
# 10                         76.4736                           1280
# 11                        259.4015                           6823
# 12                         63.6386                           2149
# 13                        482.2983                           8733
# 14                         33.3371                            363
# 15                         65.2737                           1188
# 16                         85.7276                           1369
# 17                        271.9038                           4237
# 18                       2714.2536                          20563
#
#     Late Detraining Customers mean  Late Detraining Customers median  \
# 0                           7.8182                               9.0
# 1                          53.0000                              54.0
# 2                        1286.2727                            1262.0
# 3                         247.4545                             219.0
# 4                         127.0000                             121.0
# 5                          97.6364                              99.0
# 6                         536.5455                             450.0
# 7                         174.5455                             161.0
# 8                         161.3636                             157.0
# 9                         590.4545                             620.0
# 10                        116.3636                             120.0
# 11                        620.2727                             626.0
# 12                        195.3636                             200.0
# 13                        793.9091                             769.0
# 14                         33.0000                              29.0
# 15                        108.0000                             103.0
# 16                        124.4545                             124.0
# 17                        385.1818                             436.0
# 18                       1869.3636                            1792.0
#
#     Late Detraining Customers std  Late to Total Detraining Customers Ratio  \
# 0                          3.7635                                    0.1834
# 1                          9.3381                                    0.2437
# 2                        238.6508                                    0.2587
# 3                         93.7213                                    0.3662
# 4                         41.9952                                    0.3937
# 5                         32.7667                                    0.4411
# 6                        201.4921                                    0.3859
# 7                         72.6682                                    0.6078
# 8                         36.9277                                    0.5717
# 9                        189.5006                                    0.2036
# 10                        48.8575                                    0.4794
# 11                       206.3565                                    0.5469
# 12                        37.3210                                    0.6544
# 13                       328.0300                                    0.3486
# 14                        14.9933                                    0.3785
# 15                        41.1995                                    0.3811
# 16                        36.5250                                    0.4077
# 17                       121.5326                                    0.4433
# 18                       743.2482                                    0.1969
#
#     Late Detraining Customers Avg Min Late mean  \
# 0                                       88.1818
# 1                                       65.5455
# 2                                       66.7273
# 3                                       63.6364
# 4                                       63.7273
# 5                                       62.1818
# 6                                       67.3636
# 7                                       66.8182
# 8                                       67.3636
# 9                                      101.9091
# 10                                      68.2727
# 11                                      72.0000
# 12                                      76.2727
# 13                                      95.0000
# 14                                     112.3636
# 15                                      98.6364
# 16                                      94.1818
# 17                                      92.5455
# 18                                     119.0909
#
#     Total On Time Detraining Customers sum
# 0                                      383
# 1                                     1809
# 2                                    40550
# 3                                     4712
# 4                                     2151
# 5                                     1361
# 6                                     9392
# 7                                     1239
# 8                                     1330
# 9                                    25399
# 10                                    1390
# 11                                    5653
# 12                                    1135
# 13                                   16321
# 14                                     596
# 15                                    1929
# 16                                    1989
# 17                                    5321
# 18                                   83875

# %%
#hidden tests are within this cell

# %% [markdown]
# ##### 4.6.1.1 Write to file [1 pt]
#
# Write `amtk_59_rte_stats` to a CSV file named `stu-amtk_59_rte_stats.csv`. Store the file in the `data/student` directory. Then compare it to the accompanying `fxt-amtk-59_route_stats.csv` file. It must match line for line, character for character.

# %%
# YOUR CODE HERE
filepath = parent_path.joinpath("data", "student", "stu-amtk_59_rte_stats.csv")
amtk_59_rte_stats.to_csv(filepath, index=False)

# %%
#hidden tests are within this cell

# %% [markdown]
# #### 4.6.2 _City of New Orleans_ Train 59: late detraining metrics (fiscal year and quarter)
#
# Review the central tendency, dispersion, and shape for the mean late arrival times of _City of New Orleans_ Train 59. Call the custom function named `frm.describe_numeric_column()` to return a dictionary of summary statistics. Then visualize each fiscal year and quarter data with a box plot.

# %%
# Drop missing values
amtk_59_avg_mm_late = amtk_59[COLS["late_detrn_avg_mm_late"]].dropna().reset_index(drop=True)

# Describe the column
amtk_59_avg_mm_late_describe = frm.describe_numeric_column(amtk_59_avg_mm_late)
amtk_59_avg_mm_late_describe
# Out:
# {'type': pandas.core.series.Series,
#  'name': 'Late Detraining Customers Avg Min Late',
#  'values': {'non_null': np.int64(209),
#   'missing': np.int64(0),
#   'dtype': dtype('float64')},
#  'center': {'mean': np.float64(81.14832535885168),
#   'median': 76.0,
#   'mode': np.float64(60.0)},
#  'position': {'min': 41.0,
#   '25%': np.float64(62.0),
#   '50%': np.float64(76.0),
#   '75%': np.float64(91.0),
#   'max': 172.0},
#  'spread': {'variance': 677.0788553551712,
#   'std': 26.020738947139282,
#   'range': 131.0,
#   'iqr': np.float64(29.0)},
#  'shape': {'skewness': np.float64(1.2400740474347807),
#   'kurtosis': np.float64(1.7221454158217755)}}

# %% [markdown]
# ##### 4.6.2.1 Retrieve the chart data

# %%
# Base columns for chart data
cols = [COLS["year"], COLS["quarter"], COLS["late_detrn_avg_mm_late"]]

# Get the chart data
chrt_data = detrn.get_qtr_avg_min_late(
    amtk_59_rte, cols, COLS["year_quarter"], [COLORS["amtk_blue"], COLORS["amtk_red"]]
)
chrt_data
# Out:
#     Fiscal Year Quarter  Late Detraining Customers Avg Min Late    Color
# 0                2022Q1                                   107.0  #ef3824
# 1                2022Q1                                    57.0  #ef3824
# 2                2022Q1                                    51.0  #ef3824
# 3                2022Q1                                    59.0  #ef3824
# 4                2022Q1                                    68.0  #ef3824
# ..                  ...                                     ...      ...
# 204              2024Q3                                   121.0  #ef3824
# 205              2024Q3                                    67.0  #ef3824
# 206              2024Q3                                    74.0  #ef3824
# 207              2024Q3                                    71.0  #ef3824
# 208              2024Q3                                   126.0  #ef3824
#
# [209 rows x 3 columns]

# %% [markdown]
# ##### 4.6.2.2 Preaggregate the data

# %%
# Base columns for aggregation statistics
cols = [COLS["year_quarter"], COLS["late_detrn_avg_mm_late"]]

# Pre-aggregate the data
chrt_data = frm.aggregate_data(chrt_data, cols)

# %% [markdown]
# ##### 4.6.2.3 Generate box plots

# %%
# Create chart title
txt = TRN["59"]
title_txt = (
    f"Amtrak {txt['name']} Train {txt['number']} Late Detraining Passengers\n"
    f"{txt['route']} ({txt['direction']})"
)
title = ttl.format_title(amtk_59_rte_stats, title_txt)

# Create and display vertical boxplots
chart_vertical = boxp.create_boxplot(
    data=chrt_data,
    x_shorthand="Fiscal Year Quarter:N",
    x_title="Period",
    y_shorthand="Late Detraining Customers Avg Min Late:Q",
    y_title="Average Minutes Late",
    box_size=20,
    outlier_shorthand="outliers:Q",
    color_shorthand="Color:N",
    chart_title=title,
    orient=boxp.Orient.VERTICAL,
)
chart_vertical.display()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# #### 4.6.3 _City of New Orleans_ Train 58, northbound, detraining passengers summary statistics [1 pt]
#
# Departs daily from [Union Passenger Terminal](https://www.amtrak.com/stations/NOL), New Orleans, LA ([NOL](https://www.amtrak.com/stations/NOL)). Review previous code employed to generate summary statistics for an Amtrak train. Then leverage functions available in the `amtk_network` and `amtk_detrain` modules to create three new `DataFrame` objects named `amtk_58`, `amtk_58_rte`, and `amtk_58_rte_stats`, respectively.

# %%
# Train 58 northbound
amtk_58 = ntwk.by_train_number(trains, 58)
amtk_58_rte = ntwk.create_route(amtk_58, "northbound")
amtk_58_rte_stats = detrn.get_route_sum_stats(
    amtk_58_rte, COLS["station_code"], AGG["columns"], AGG["funcs"], rte_cols
)
amtk_58_rte_stats
# Out:
#     Train Number Arrival Station Code          Arrival Station        State  \
# 0             58                  HMD                  Hammond    Louisiana
# 1             58                  MCB                   McComb  Mississippi
# 2             58                  BRH               Brookhaven  Mississippi
# 3             58                  HAZ               Hazlehurst  Mississippi
# 4             58                  JAN                  Jackson  Mississippi
# 5             58                  YAZ               Yazoo City  Mississippi
# 6             58                  GWD                Greenwood  Mississippi
# 7             58                  MKS                    Marks  Mississippi
# 8             58                  MEM                  Memphis    Tennessee
# 9             58                  NBN        Newbern-Dyersburg    Tennessee
# 10            58                  FTN                   Fulton     Kentucky
# 11            58                  CDL      Carbondale (Amtrak)     Illinois
# 12            58                  CEN                Centralia     Illinois
# 13            58                  EFG                Effingham     Illinois
# 14            58                  MAT                  Mattoon     Illinois
# 15            58                  CHM         Champaign-Urbana     Illinois
# 16            58                  KKI                 Kankakee     Illinois
# 17            58                  HMW                 Homewood     Illinois
# 18            58                  CHI  Chicago (Union Station)     Illinois
#
#      Latitude  Longitude  Train Arrivals  Total Detraining Customers sum  \
# 0   30.507180 -90.462169              11                            2264
# 1   31.244467 -90.451334              11                            1698
# 2   31.582961 -90.441070              11                            1558
# 3   31.861320 -90.394347              11                             959
# 4   32.300808 -90.190936              11                           21050
# 5   32.848477 -90.415230              11                             993
# 6   33.517159 -90.176454              11                            4154
# 7   34.258227 -90.272342              11                            2664
# 8   35.132458 -90.059109              11                           43340
# 9   36.112711 -89.262264              11                            1459
# 10  36.525704 -88.888772              11                            2237
# 11  37.724235 -89.216628              11                            6995
# 12  38.527531 -89.136118              11                            1014
# 13  39.117059 -88.547110              11                            1117
# 14  39.482730 -88.376045              11                            1363
# 15  40.115843 -88.241366              11                           11355
# 16  41.119259 -87.865430              11                            2736
# 17  41.562446 -87.668685              11                           15746
# 18  41.878992 -87.641015              11                          150011
#
#     Total Detraining Customers mean  Total Detraining Customers median  \
# 0                          205.8182                              198.0
# 1                          154.3636                              155.0
# 2                          141.6364                              150.0
# 3                           87.1818                               78.0
# 4                         1913.6364                             1970.0
# 5                           90.2727                               72.0
# 6                          377.6364                              379.0
# 7                          242.1818                              208.0
# 8                         3940.0000                             4042.0
# 9                          132.6364                              145.0
# 10                         203.3636                              200.0
# 11                         635.9091                              669.0
# 12                          92.1818                               91.0
# 13                         101.5455                               98.0
# 14                         123.9091                              137.0
# 15                        1032.2727                             1043.0
# 16                         248.7273                              247.0
# 17                        1431.4545                             1305.0
# 18                       13637.3636                            13166.0
#
#     Total Detraining Customers std  Late Detraining Customers sum  \
# 0                          69.5698                           1126
# 1                          48.5042                           1025
# 2                          60.3892                            985
# 3                          31.1731                            657
# 4                         573.9058                           2584
# 5                          50.3212                            200
# 6                         131.9661                           1155
# 7                          69.0924                           1112
# 8                        1226.0761                          11764
# 9                          55.9665                            639
# 10                         73.6441                            867
# 11                        146.1687                           2151
# 12                         23.1768                            360
# 13                         27.8186                            480
# 14                         28.8252                            565
# 15                        201.8505                           4950
# 16                         62.6324                           1275
# 17                        409.8503                           8037
# 18                       2608.6811                          34699
#
#     Late Detraining Customers mean  Late Detraining Customers median  \
# 0                         102.3636                              98.0
# 1                          93.1818                              89.0
# 2                          89.5455                              78.0
# 3                          59.7273                              55.0
# 4                         234.9091                             203.0
# 5                          18.1818                              17.0
# 6                         105.0000                              96.0
# 7                         101.0909                             106.0
# 8                        1069.4545                             870.0
# 9                          58.0909                              50.0
# 10                         78.8182                              80.0
# 11                        195.5455                             170.0
# 12                         32.7273                              32.0
# 13                         43.6364                              40.0
# 14                         51.3636                              49.0
# 15                        450.0000                             394.0
# 16                        115.9091                             112.0
# 17                        730.6364                             650.0
# 18                       3154.4545                            3033.0
#
#     Late Detraining Customers std  Late to Total Detraining Customers Ratio  \
# 0                         40.1952                                    0.4973
# 1                         30.8539                                    0.6037
# 2                         39.7577                                    0.6322
# 3                         22.4058                                    0.6851
# 4                        163.0825                                    0.1228
# 5                         10.9619                                    0.2014
# 6                         48.0687                                    0.2780
# 7                         42.7819                                    0.4174
# 8                        538.3936                                    0.2714
# 9                         28.1370                                    0.4380
# 10                        32.5786                                    0.3876
# 11                        60.2534                                    0.3075
# 12                        12.2889                                    0.3550
# 13                        16.2989                                    0.4297
# 14                        15.3445                                    0.4145
# 15                       124.2578                                    0.4359
# 16                        35.9790                                    0.4660
# 17                       212.4577                                    0.5104
# 18                      1418.1027                                    0.2313
#
#     Late Detraining Customers Avg Min Late mean  \
# 0                                       30.6364
# 1                                       34.4545
# 2                                       41.9091
# 3                                       38.3636
# 4                                       63.2727
# 5                                       60.8182
# 6                                       61.6364
# 7                                       59.3636
# 8                                       74.1818
# 9                                       62.0909
# 10                                      76.0909
# 11                                      83.9091
# 12                                      80.9091
# 13                                      86.6364
# 14                                      83.0000
# 15                                      81.8182
# 16                                      75.7273
# 17                                      78.4545
# 18                                      95.2727
#
#     Total On Time Detraining Customers sum
# 0                                     1138
# 1                                      673
# 2                                      573
# 3                                      302
# 4                                    18466
# 5                                      793
# 6                                     2999
# 7                                     1552
# 8                                    31576
# 9                                      820
# 10                                    1370
# 11                                    4844
# 12                                     654
# 13                                     637
# 14                                     798
# 15                                    6405
# 16                                    1461
# 17                                    7709
# 18                                  115312

# %%
#hidden tests are within this cell

# %% [markdown]
# ##### 4.6.3.1 Write to file [1 pt]
#
# Write `amtk_58_rte_stats` to a CSV file named `stu-amtk_58_rte_stats.csv`. Store the file in the `data/student` directory. Then compare it to the accompanying `fxt-amtk-58_route_stats.csv` file. It must match line for line, character for character.

# %%
# YOUR CODE HERE
filepath = parent_path.joinpath("data", "student", "stu-amtk_58_rte_stats.csv")
amtk_58_rte_stats.to_csv(filepath, index=False)

# %%
#hidden tests are within this cell

# %% [markdown]
# #### 4.6.4 _City of New Orleans_ Train 58: late detraining metrics (fiscal year and quarter)
#
# Review the central tendency, dispersion, and shape for the mean late arrival times of _City of New Orleans_ Train 58. Call the custom function named `frm.describe_numeric_column()` to return a dictionary of summary statistics. Then visualize each fiscal year and quarter data with a box plot.

# %%
# Drop missing values
amtk_58_avg_mm_late = amtk_58[COLS["late_detrn_avg_mm_late"]].dropna().reset_index(drop=True)

# Describe the column
amtk_58_avg_mm_late_describe = frm.describe_numeric_column(amtk_58_avg_mm_late)
amtk_58_avg_mm_late_describe
# Out:
# {'type': pandas.core.series.Series,
#  'name': 'Late Detraining Customers Avg Min Late',
#  'values': {'non_null': np.int64(209),
#   'missing': np.int64(0),
#   'dtype': dtype('float64')},
#  'center': {'mean': np.float64(66.76555023923444),
#   'median': 62.0,
#   'mode': np.float64(76.0)},
#  'position': {'min': 23.0,
#   '25%': np.float64(45.0),
#   '50%': np.float64(62.0),
#   '75%': np.float64(81.0),
#   'max': 221.0},
#  'spread': {'variance': 960.7764998159735,
#   'std': 30.996394948702882,
#   'range': 198.0,
#   'iqr': np.float64(36.0)},
#  'shape': {'skewness': np.float64(1.4509054944484152),
#   'kurtosis': np.float64(3.869952017175466)}}

# %% [markdown]
# ##### 4.6.4.1 Retrieve the chart data [1 pt]

# %%
# Base columns for average minutes late
cols = [COLS["year"], COLS["quarter"], COLS["late_detrn_avg_mm_late"]]

# Chart data
chrt_data = detrn.get_qtr_avg_min_late(
    amtk_58_rte, cols, COLS["year_quarter"], [COLORS["amtk_blue"], COLORS["amtk_red"]]
)
chrt_data
# Out:
#     Fiscal Year Quarter  Late Detraining Customers Avg Min Late    Color
# 0                2022Q1                                    34.0  #ef3824
# 1                2022Q1                                    35.0  #ef3824
# 2                2022Q1                                    40.0  #ef3824
# 3                2022Q1                                    56.0  #ef3824
# 4                2022Q1                                    59.0  #ef3824
# ..                  ...                                     ...      ...
# 204              2024Q3                                    76.0  #ef3824
# 205              2024Q3                                    88.0  #ef3824
# 206              2024Q3                                    84.0  #ef3824
# 207              2024Q3                                    77.0  #ef3824
# 208              2024Q3                                   145.0  #ef3824
#
# [209 rows x 3 columns]

# %%
#hidden tests are within this cell

# %% [markdown]
# ##### 4.6.4.2 Preaggregate the data

# %%
# Base columns for average minutes late
cols = [COLS["year_quarter"], COLS["late_detrn_avg_mm_late"]]

# Pre-aggregate the data
chrt_data = frm.aggregate_data(chrt_data, cols)

# %% [markdown]
# ##### 4.6.4.3 Generate box plots

# %%
# Create chart title
txt = TRN["58"]
title_txt = (
    f"Amtrak {txt['name']} Train {txt['number']} Late Detraining Passengers\n"
    f"{txt['route']} ({txt['direction']})"
)
title = ttl.format_title(amtk_58_rte_stats, title_txt)

# Create and display vertical boxplots
chart_vertical = boxp.create_boxplot(
    data=chrt_data,
    x_shorthand="Fiscal Year Quarter:N",
    x_title="Period",
    y_shorthand="Late Detraining Customers Avg Min Late:Q",
    y_title="Average Minutes Late",
    box_size=20,
    outlier_shorthand="outliers:Q",
    color_shorthand="Color:N",
    chart_title=title,
    orient=boxp.Orient.VERTICAL,
)
chart_vertical.display()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## 5.0 Watermark

# %%
# %load_ext watermark
# %watermark -h -i -iv -m -v
